# %% [markdown]
# ## Phiên bản song song hóa 1 được tối ưu bằng stream

# %% [markdown]
# ### Lý thuyết
# - `CUDA Stream` là một chuỗi các thao tác thực thi trên GPU được lên lịch và xử lý theo thứ tự.
#
# - Mỗi stream chạy độc lập, các thao tác bên trong một stream được thực hiện tuần tự, nhưng nhiều stream khác nhau có thể thực thi song song nếu tài nguyên GPU cho phép.
#
# - Trong lập trình song song, ta thuờng làm 3 việc:
#     - Copy dữ liệu từ host → device (cuda.to_device)
#     - Chạy kernel trên device (@cuda.jit)
#     - Copy kết quả từ device → host (copy_to_host)
#
# - Nếu chỉ song song hóa bình thuờng thìcác thao tác trên diễn ra tuần tự trên default stream ⇒ dẫn đến `bottleneck` nếu phải lặp lại nhiều lần.
#
# - Stream cho phép `xử lý đồng thời` các thao tác này khi ta:
#     - Chạy nhiều kernel không phụ thuộc nhau
#     - Overlap tính toán và truyền dữ liệu

# %%
import os
import sys
from pathlib import Path

# %%
current_path = Path().resolve()
while current_path.name != "APP-project":
    if current_path.parent == current_path:
        raise FileNotFoundError("❌ Không tìm thấy thư mục gốc 'APP-project'")
    current_path = current_path.parent

os.chdir(current_path)
# print(f"📂 Project root set to: {current_path}")

# %%
sys.path.append('Src')
from Src import func as func

import numpy as np
import matplotlib.pyplot as plt

from numpy.lib.stride_tricks import as_strided

import random
import math
import time

from numba import cuda, float32

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Class Conv2D

# %% [markdown]
# #### Bổ trợ

# %%
@cuda.jit
def mul_mat_kernel(A, B, C):
    row, col = cuda.grid(2)
    if row < C.shape[0] and col < C.shape[1]:
        acc = 0.0
        for k in range(A.shape[1]):
            acc += A[row, k] * B[k, col]
        C[row, col] = acc

@cuda.jit
def sum_axis0_kernel(arr, out):
    col = cuda.grid(1)
    if col < arr.shape[1]:
        total = 0.0
        for i in range(arr.shape[0]):
            total += arr[i, col]
        out[col] = total

@cuda.jit
def im2col_kernel(input_padded, cols, H, W, C, K, S, out_h, out_w):
    idx = cuda.grid(1)
    total = out_h * out_w
    if idx < total:
        i = idx // out_w
        j = idx % out_w
        for ki in range(K):
            for kj in range(K):
                for c in range(C):
                    row = i * S + ki
                    col = j * S + kj
                    val = input_padded[row, col, c]
                    cols[idx, c * K * K + ki * K + kj] = val

@cuda.jit
def col2im_kernel(dcols, grad_input_padded, H, W, C, K, S, out_h, out_w):
    idx = cuda.grid(1)
    total = out_h * out_w
    if idx < total:
        i = idx // out_w
        j = idx % out_w
        for ki in range(K):
            for kj in range(K):
                for c in range(C):
                    row = i * S + ki
                    col = j * S + kj
                    cuda.atomic.add(grad_input_padded, (row, col, c),
                                    dcols[idx, c * K * K + ki * K + kj])

def dot_cuda(A, B):
    A = np.ascontiguousarray(A)
    B = np.ascontiguousarray(B)
    M, K = A.shape
    K2, N = B.shape
    assert K == K2
    C = np.zeros((M, N), dtype=np.float32)

    stream = cuda.stream()
    d_A = cuda.to_device(A, stream=stream)
    d_B = cuda.to_device(B, stream=stream)
    d_C = cuda.device_array((M, N), dtype=np.float32, stream=stream)

    threads = (32, 32)
    blocks = ((M + threads[0] - 1) // threads[0], (N + threads[1] - 1) // threads[1])
    mul_mat_kernel[blocks, threads, stream](d_A, d_B, d_C)
    
    result = np.empty_like(C)
    d_C.copy_to_host(result, stream=stream)
    stream.synchronize()
    return result

def sum_axis0_cuda(arr):
    arr = np.ascontiguousarray(arr)
    N = arr.shape[1]
    
    stream = cuda.stream()
    d_arr = cuda.to_device(arr, stream=stream)
    d_out = cuda.device_array(N, dtype=np.float32, stream=stream)

    threads = 256
    blocks = (N + threads - 1) // threads
    sum_axis0_kernel[blocks, threads, stream](d_arr, d_out)

    result = np.empty_like(d_out.copy_to_host())
    d_out.copy_to_host(result, stream=stream)
    stream.synchronize()
    return result

def im2col_cuda(x_padded, kernel_size, stride):
    H, W, C = x_padded.shape
    K = kernel_size
    S = stride
    out_h = (H - K) // S + 1
    out_w = (W - K) // S + 1
    cols = np.zeros((out_h * out_w, K * K * C), dtype=np.float32)

    stream = cuda.stream()
    d_input = cuda.to_device(x_padded, stream=stream)
    d_cols = cuda.to_device(cols, stream=stream)

    threads = 256
    blocks = (out_h * out_w + threads - 1) // threads
    im2col_kernel[blocks, threads, stream](d_input, d_cols, H, W, C, K, S, out_h, out_w)

    result = np.empty_like(cols)
    d_cols.copy_to_host(result, stream=stream)
    stream.synchronize()
    return result, out_h, out_w

def col2im_cuda(dcols, input_shape, kernel_size, stride, padding):
    H, W, C = input_shape
    H_pad, W_pad = H + 2 * padding, W + 2 * padding
    K = kernel_size
    S = stride
    out_h = (H_pad - K) // S + 1
    out_w = (W_pad - K) // S + 1

    grad_input_padded = np.zeros((H_pad, W_pad, C), dtype=np.float32)

    stream = cuda.stream()
    d_dcols = cuda.to_device(dcols, stream=stream)
    d_grad_input = cuda.to_device(grad_input_padded, stream=stream)

    threads = 256
    blocks = (out_h * out_w + threads - 1) // threads
    col2im_kernel[blocks, threads, stream](d_dcols, d_grad_input, H_pad, W_pad, C, K, S, out_h, out_w)

    d_grad_input.copy_to_host(grad_input_padded, stream=stream)
    stream.synchronize()

    if padding > 0:
        return grad_input_padded[padding:-padding, padding:-padding, :]
    return grad_input_padded

# %% [markdown]
# #### Class

# %%
class Conv2D_CUDA:
    def __init__(self, in_channels, out_channels, kernel_size=3, padding=0, stride=1):
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.padding = padding
        self.stride = stride

        limit = 0.1
        self.kernels = np.random.uniform(-limit, limit, 
                        (out_channels, kernel_size * kernel_size * in_channels)).astype(np.float32)
        self.biases = np.random.uniform(-limit, limit, out_channels).astype(np.float32)

        self.v_kernels = np.zeros_like(self.kernels)
        self.v_biases = np.zeros_like(self.biases)

    def forward(self, input_data):
        self.input_data = input_data
        self.input_padded = np.pad(input_data, ((self.padding, self.padding), 
                                                 (self.padding, self.padding), (0, 0)), mode='constant')
        self.cols, self.out_h, self.out_w = im2col_cuda(self.input_padded, self.kernel_size, self.stride)

        self.cols = np.ascontiguousarray(self.cols, dtype=np.float32)
        self.kernels = np.ascontiguousarray(self.kernels, dtype=np.float32)

        out = dot_cuda(self.cols, self.kernels.T)
        out += self.biases

        return out.reshape(self.out_h, self.out_w, self.out_channels)

    def backward(self, grad_output):
        dout_flat = grad_output.reshape(-1, self.out_channels).astype(np.float32)

        self.grad_kernels = dot_cuda(dout_flat.T, self.cols)
        self.grad_biases = sum_axis0_cuda(dout_flat)
        dcols = dot_cuda(dout_flat, self.kernels)
        grad_input = col2im_cuda(dcols, self.input_data.shape, self.kernel_size, self.stride, self.padding)

        return grad_input

    def step(self, lr, momentum=0.9):
        self.v_kernels = momentum * self.v_kernels - lr * self.grad_kernels
        self.v_biases = momentum * self.v_biases - lr * self.grad_biases
        self.kernels += self.v_kernels
        self.biases += self.v_biases

# %% [markdown]
# #### Test

# %%
X_train, y_train_onehot, X_test, y_test_onehot = func.preprocess_cifar10_data()

# in shape của dữ liệu
print(f"X_train shape: {X_train.shape}")
print(f"y_train_onehot shape: {y_train_onehot.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test_onehot shape: {y_test_onehot.shape}")
# Out:
# X_train shape: (50000, 32, 32, 3)
# y_train_onehot shape: (50000, 10)
# X_test shape: (10000, 32, 32, 3)
# y_test_onehot shape: (10000, 10)

# %%
# # Test Conv2D_CUDA với 1 ảnh từ CIFAR-10
# # Giả lập quy trình forward -> backward -> step

# # Lấy 1 sample từ CIFAR-10
# x = X_train[0]                    # (32, 32, 3)
# y = y_train_onehot[0]            # (10,)

# # Khởi tạo Conv2D_CUDA layer
# conv = Conv2D_CUDA(in_channels=3, out_channels=8, kernel_size=3, padding=1, stride=1)

# # ============ FORWARD ============
# out = conv.forward(x)            # (32, 32, 8)
# print(" Forward output shape:", out.shape)
# print(f" Output stats - mean: {out.mean():.6f}, std: {out.std():.6f}, min: {out.min():.6f}, max: {out.max():.6f}")

# # ============ FAKE LOSS GRADIENT ============
# # Tạo grad_output giả lập từ loss, shape khớp output
# grad_output = np.random.randn(*out.shape).astype(np.float32)

# # ============ BACKWARD ============
# grad_input = conv.backward(grad_output)  # (32, 32, 3)
# print(" Backward grad_input shape:", grad_input.shape)
# print(f" Grad stats - mean: {grad_input.mean():.6f}, std: {grad_input.std():.6f}")

# # ============ STEP ============
# conv.step(lr=0.001, momentum=0.9)
# print(" Step hoàn tất. Trọng số đã cập nhật.")
# Out:
# ✅ Forward output shape: (32, 32, 8)
# 📊 Output stats - mean: 0.047816, std: 0.153590, min: -0.454574, max: 0.524280
# 🔁 Backward grad_input shape: (32, 32, 3)
# 📉 Grad stats - mean: -0.006091, std: 0.476801
# ✅ Step hoàn tất. Trọng số đã cập nhật.

# %% [markdown]
# ### **Class Relu**

# %% [markdown]
# #### Class

# %%
# CUDA kernel for ReLU forward: y = max(0, x)
@cuda.jit
def relu_forward_kernel(x, y):
    idx = cuda.grid(1)
    if idx < x.size:
        y[idx] = max(0.0, x[idx])

# CUDA kernel for ReLU backward: dy = grad_output * (x > 0)
@cuda.jit
def relu_backward_kernel(grad_output, x, grad_input):
    idx = cuda.grid(1)
    if idx < grad_output.size:
        grad_input[idx] = grad_output[idx] if x[idx] > 0 else 0.0

# ReLU_CUDA class
class ReLU_CUDA:
    def forward(self, x):
        self.input_shape = x.shape
        x_flat = x.flatten().astype(np.float32)
        y_flat = np.zeros_like(x_flat)

        stream = cuda.stream()

        d_x = cuda.to_device(x_flat, stream=stream)
        d_y = cuda.device_array_like(y_flat, stream=stream)

        threads = 256
        blocks = (x_flat.size + threads - 1) // threads
        relu_forward_kernel[blocks, threads, stream](d_x, d_y)

        result = np.empty_like(y_flat)
        d_y.copy_to_host(result, stream=stream)
        stream.synchronize()

        self.input_flat = x_flat  # Save for backward
        self.output_flat = result
        return result.reshape(self.input_shape)

    def backward(self, grad_output):
        grad_output_flat = grad_output.flatten().astype(np.float32)
        grad_input_flat = np.zeros_like(grad_output_flat)

        stream = cuda.stream()

        d_grad_output = cuda.to_device(grad_output_flat, stream=stream)
        d_input = cuda.to_device(self.input_flat, stream=stream)
        d_grad_input = cuda.device_array_like(grad_input_flat, stream=stream)

        threads = 256
        blocks = (grad_output_flat.size + threads - 1) // threads
        relu_backward_kernel[blocks, threads, stream](d_grad_output, d_input, d_grad_input)

        result = np.empty_like(grad_input_flat)
        d_grad_input.copy_to_host(result, stream=stream)
        stream.synchronize()

        return result.reshape(self.input_shape)

# %% [markdown]
# #### Test

# %%
# # Khởi tạo ReLU
# relu = ReLU_CUDA()

# # FORWARD từ output conv trước đó
# out_relu = relu.forward(out)
# print("ReLU Output - shape:", out_relu.shape)
# print(f" ReLU stats - mean: {out_relu.mean():.6f}, std: {out_relu.std():.6f}, zeros: {np.sum(out_relu == 0)} / {out_relu.size}")

# # BACKWARD với grad giả lập
# grad_output = np.random.randn(*out.shape).astype(np.float32)
# grad_relu = relu.backward(grad_output)
# print(" ReLU Backward - shape:", grad_relu.shape)
# print(f" Grad stats - mean: {grad_relu.mean():.6f}, std: {grad_relu.std():.6f}")
# Out:
# 🔋 ReLU Output - shape: (32, 32, 8)
# 📊 ReLU stats - mean: 0.084761, std: 0.110734, zeros: 3062 / 8192
# 🔁 ReLU Backward - shape: (32, 32, 8)
# 📉 Grad stats - mean: -0.004697, std: 0.802538

# %% [markdown]
# ### **Class MaxPool2D**

# %%
# 1. MaxPool2D - FORWARD kernel
@cuda.jit
def maxpool2d_forward_kernel(x, out, max_indices, k, s, H, W, C, out_h, out_w):
    idx = cuda.grid(1)
    total = out_h * out_w * C
    if idx < total:
        ow = idx % out_w
        oh = (idx // out_w) % out_h
        c = idx // (out_h * out_w)

        max_val = -1e20
        max_idx = 0
        for i in range(k):
            for j in range(k):
                h = oh * s + i
                w = ow * s + j
                val = x[h, w, c]
                if val > max_val:
                    max_val = val
                    max_idx = i * k + j
        out[oh, ow, c] = max_val
        max_indices[oh, ow, c] = max_idx

# 2. MaxPool2D - BACKWARD kernel
@cuda.jit
def maxpool2d_backward_kernel(d_out, max_indices, d_input, k, s, out_h, out_w, H, W, C):
    idx = cuda.grid(1)
    total = out_h * out_w * C
    if idx < total:
        ow = idx % out_w
        oh = (idx // out_w) % out_h
        c = idx // (out_h * out_w)

        max_idx = max_indices[oh, ow, c]
        u = max_idx // k
        v = max_idx % k

        h = oh * s + u
        w = ow * s + v

        cuda.atomic.add(d_input, (h, w, c), d_out[oh, ow, c])

# 3. MaxPool2D_CUDA class
class MaxPool2D_CUDA:
    def __init__(self, kernel_size=2, stride=2):
        self.kernel_size = kernel_size
        self.stride = stride

    def forward(self, x):
        self.input = x
        H, W, C = x.shape
        k = self.kernel_size
        s = self.stride

        out_h = (H - k) // s + 1
        out_w = (W - k) // s + 1

        out = np.zeros((out_h, out_w, C), dtype=np.float32)
        max_indices = np.zeros_like(out, dtype=np.int32)

        stream = cuda.stream()

        d_x = cuda.to_device(x, stream=stream)
        d_out = cuda.device_array_like(out, stream=stream)
        d_max_indices = cuda.device_array_like(max_indices, stream=stream)

        threads = 256
        blocks = (out_h * out_w * C + threads - 1) // threads
        maxpool2d_forward_kernel[blocks, threads, stream](d_x, d_out, d_max_indices, k, s, H, W, C, out_h, out_w)

        result_out = np.empty_like(out)
        result_indices = np.empty_like(max_indices)

        d_out.copy_to_host(result_out, stream=stream)
        d_max_indices.copy_to_host(result_indices, stream=stream)
        stream.synchronize()

        self.max_indices = result_indices
        self.out_shape = out.shape
        return result_out

    def backward(self, d_out):
        H, W, C = self.input.shape
        k = self.kernel_size
        s = self.stride
        out_h, out_w, _ = self.out_shape

        d_input = np.zeros_like(self.input, dtype=np.float32)

        stream = cuda.stream()

        d_dout = cuda.to_device(np.ascontiguousarray(d_out), stream=stream)
        d_max_indices = cuda.to_device(self.max_indices, stream=stream)
        d_dinput = cuda.to_device(d_input, stream=stream)

        threads = 256
        blocks = (out_h * out_w * C + threads - 1) // threads
        maxpool2d_backward_kernel[blocks, threads, stream](d_dout, d_max_indices, d_dinput, k, s, out_h, out_w, H, W, C)

        result = np.empty_like(d_input)
        d_dinput.copy_to_host(result, stream=stream)
        stream.synchronize()
        return result

# %% [markdown]
# #### Test

# %%
# pool = MaxPool2D_CUDA(kernel_size=2, stride=2)

# out_pool = pool.forward(out_relu)
# print("MaxPool output shape:", out_pool.shape)
# print(" Zero count:", np.sum(out_pool == 0))

# # Backward với grad giả
# grad_fake = np.random.randn(*out_pool.shape).astype(np.float32)
# grad_pool = pool.backward(grad_fake)
# print(" Backward shape:", grad_pool.shape)
# print(f" Grad stats: mean={grad_pool.mean():.6f}, std={grad_pool.std():.6f}")
# Out:
# ✅ MaxPool output shape: (16, 16, 8)
# 🧊 Zero count: 616
# 🔁 Backward shape: (32, 32, 8)
# 📉 Grad stats: mean=-0.002709, std=0.483338

# %% [markdown]
# ### **Conv Block**

# %%
class ConvBlock_CUDA:
    def __init__(self, in_channels, out_channels, num_convs=2, padding=0, stride=1):
        self.convs = []
        self.relus = []

        for _ in range(num_convs):
            conv = Conv2D_CUDA(in_channels, out_channels, kernel_size=3, padding=padding, stride=stride)
            relu = ReLU_CUDA()
            self.convs.append(conv)
            self.relus.append(relu)
            in_channels = out_channels  # chuẩn bị cho conv tiếp theo

        self.pool = MaxPool2D_CUDA(kernel_size=2, stride=2)

    def forward(self, input):
        x = input
        for conv, relu in zip(self.convs, self.relus):
            x = conv.forward(x)
            x = relu.forward(x)
        x = self.pool.forward(x)
        return x

    def backward(self, d_out):
        d_out = self.pool.backward(d_out)
        for conv, relu in zip(reversed(self.convs), reversed(self.relus)):
            d_out = relu.backward(d_out)
            d_out = conv.backward(d_out)
        return d_out

    def step(self, learning_rate, momentum=0.9):
        for conv in self.convs:
            conv.step(learning_rate, momentum)

# %% [markdown]
# #### Test

# %%
# # ======== LẤY MẪU DỮ LIỆU ========
# x = X_train[0]                    # (32, 32, 3)
# y = y_train_onehot[0]            # (10,)

# # ======== KHỞI TẠO BLOCK ========
# block = ConvBlock_CUDA(in_channels=3, out_channels=8, num_convs=2, padding=1, stride=1)

# # ======== FORWARD ========
# out = block.forward(x)
# print(" ConvBlock forward output shape:", out.shape)
# print(f" mean={out.mean():.6f}, std={out.std():.6f}, min={out.min():.6f}, max={out.max():.6f}")

# # ======== GIẢ GRADIENT (từ FC hoặc loss) ========
# grad_fake = np.random.randn(*out.shape).astype(np.float32)

# # ======== BACKWARD ========
# grad_input = block.backward(grad_fake)
# print(" ConvBlock backward grad_input shape:", grad_input.shape)
# print(f" mean={grad_input.mean():.6f}, std={grad_input.std():.6f}")

# # ======== STEP (update trọng số) ========
# block.step(learning_rate=0.001, momentum=0.9)
# print(" Step hoàn tất, các Conv2D bên trong đã được cập nhật.")
# Out:
# ✅ ConvBlock forward output shape: (16, 16, 8)
# 📊 mean=0.040475, std=0.035058, min=0.000000, max=0.105888
# 🔁 ConvBlock backward grad_input shape: (32, 32, 3)
# 📉 mean=-0.000203, std=0.034676
# ✅ Step hoàn tất, các Conv2D bên trong đã được cập nhật.

# %% [markdown]
# ### **Flatten**

# %%
# Flatten forward kernel: flatten 3D -> 1D
@cuda.jit
def flatten_forward_kernel(x, y):
    idx = cuda.grid(1)
    if idx < x.size:
        y[idx] = x[idx]

# Flatten backward kernel: reshape 1D -> 3D
@cuda.jit
def flatten_backward_kernel(grad_output, grad_input):
    idx = cuda.grid(1)
    if idx < grad_output.size:
        grad_input[idx] = grad_output[idx]

# Flatten_CUDA class
class Flatten_CUDA:
    def forward(self, input):
        self.input_shape = input.shape  # (H, W, C)
        x = input.flatten().astype(np.float32)
        y = np.empty_like(x)

        stream = cuda.stream()

        d_x = cuda.to_device(x, stream=stream)
        d_y = cuda.device_array_like(x, stream=stream)

        threads = 256
        blocks = (x.size + threads - 1) // threads
        flatten_forward_kernel[blocks, threads, stream](d_x, d_y)

        d_y.copy_to_host(y, stream=stream)
        stream.synchronize()

        return y

    def backward(self, grad_output):
        grad_output_flat = grad_output.flatten().astype(np.float32)
        grad_input_flat = np.empty_like(grad_output_flat)

        stream = cuda.stream()

        d_out = cuda.to_device(grad_output_flat, stream=stream)
        d_in = cuda.device_array_like(grad_output_flat, stream=stream)

        threads = 256
        blocks = (grad_output_flat.size + threads - 1) // threads
        flatten_backward_kernel[blocks, threads, stream](d_out, d_in)

        d_in.copy_to_host(grad_input_flat, stream=stream)
        stream.synchronize()

        return grad_input_flat.reshape(self.input_shape)

# %% [markdown]
# ### **Fully Connected Layer**

# %%
class FullyConnected_CUDA:
    def __init__(self, in_dim, out_dim):
        limit = 0.01
        self.W = np.random.uniform(-limit, limit, (in_dim, out_dim)).astype(np.float32)
        self.b = np.random.uniform(-limit, limit, out_dim).astype(np.float32)

        self.v_W = np.zeros_like(self.W)
        self.v_b = np.zeros_like(self.b)

    def forward(self, x):
        self.input = x.astype(np.float32)
        self.input_flat = np.ascontiguousarray(self.input).reshape(1, -1)  # (1, in_dim)

        W = np.ascontiguousarray(self.W)                                   # (in_dim, out_dim)
        out = dot_cuda(self.input_flat, W)                                 # (1, out_dim)
        return out[0] + self.b                                             # (out_dim,)

    def backward(self, grad_output):
        grad_output = grad_output.astype(np.float32).reshape(1, -1)        # (1, out_dim)

        self.grad_W = dot_cuda(self.input_flat.T, grad_output)             # (in_dim, out_dim)
        self.grad_b = grad_output[0]                                       # (out_dim,)
        grad_input = dot_cuda(grad_output, self.W.T)                       # (1, in_dim)

        return grad_input[0]                                               # (in_dim,)

    def step(self, learning_rate, momentum=0.9):
        self.v_W = momentum * self.v_W - learning_rate * self.grad_W
        self.v_b = momentum * self.v_b - learning_rate * self.grad_b
        self.W += self.v_W
        self.b += self.v_b

# %% [markdown]
# #### Test

# %%
# # Dữ liệu giả lập output sau ConvBlock
# x = np.random.randn(16, 16, 8).astype(np.float32)

# flatten = Flatten_CUDA()
# x_flat = flatten.forward(x)
# print(" Flatten shape:", x_flat.shape)

# fc = FullyConnected_CUDA(in_dim=x_flat.shape[0], out_dim=10)
# out = fc.forward(x_flat)
# print(" FC output:", out.shape)

# grad_output = np.random.randn(10).astype(np.float32)
# grad_fc = fc.backward(grad_output)
# grad_input = flatten.backward(grad_fc)

# print(" Backward shapes:", grad_fc.shape, grad_input.shape)
# fc.step(learning_rate=0.001, momentum=0.9)
# Out:
# ✅ Flatten shape: (2048,)
# ✅ FC output: (10,)
# 🔁 Backward shapes: (2048,) (16, 16, 8)

# %% [markdown]
# ### **Relu cho Vector**

# %%
# CUDA kernels for ReLUVector
@cuda.jit
def relu_vector_forward_kernel(x, y):
    idx = cuda.grid(1)
    if idx < x.size:
        y[idx] = max(0.0, x[idx])

@cuda.jit
def relu_vector_backward_kernel(grad_output, x, grad_input):
    idx = cuda.grid(1)
    if idx < grad_output.size:
        grad_input[idx] = grad_output[idx] if x[idx] > 0 else 0.0

# ReLUVector_CUDA class
class ReLUVector_CUDA:
    def forward(self, x):
        self.input = x.astype(np.float32)
        self.output = np.empty_like(self.input)

        stream = cuda.stream()

        d_x = cuda.to_device(self.input, stream=stream)
        d_y = cuda.device_array_like(self.input, stream=stream)

        threads = 256
        blocks = (self.input.size + threads - 1) // threads
        relu_vector_forward_kernel[blocks, threads, stream](d_x, d_y)

        d_y.copy_to_host(self.output, stream=stream)
        stream.synchronize()

        return self.output

    def backward(self, grad_output):
        grad_output = grad_output.astype(np.float32)
        grad_input = np.empty_like(grad_output)

        stream = cuda.stream()

        d_grad_output = cuda.to_device(grad_output, stream=stream)
        d_input = cuda.to_device(self.input, stream=stream)
        d_grad_input = cuda.device_array_like(grad_output, stream=stream)

        threads = 256
        blocks = (grad_output.size + threads - 1) // threads
        relu_vector_backward_kernel[blocks, threads, stream](d_grad_output, d_input, d_grad_input)

        d_grad_input.copy_to_host(grad_input, stream=stream)
        stream.synchronize()

        return grad_input

# %% [markdown]
# ### **Softmax + CrossEntropyLoss**

# %%
class Softmax_CUDA:
    def forward(self, x):
        self.input = x.astype(np.float32)
        x_stable = self.input - np.max(self.input)
        exps = np.exp(x_stable)
        self.output = exps / np.sum(exps)
        return self.output

class CrossEntropyLoss_CUDA:
    def forward(self, pred_probs, target_onehot):
        self.pred_probs = pred_probs.astype(np.float32)
        self.target_onehot = target_onehot.astype(np.float32)
        return -np.sum(self.target_onehot * np.log(self.pred_probs + 1e-12))

    def backward(self):
        return self.pred_probs - self.target_onehot

# %% [markdown]
# ### **Class Cấu Trúc**

# %%
class SimpleCNN_CUDA:
    def __init__(self):
        self.block1 = ConvBlock_CUDA(3, 64, num_convs=2, padding=1)
        self.block2 = ConvBlock_CUDA(64, 128, num_convs=2, padding=1)
        self.block3 = ConvBlock_CUDA(128, 256, num_convs=2, padding=1)

        self.flatten = Flatten_CUDA()
        self.fc1 = FullyConnected_CUDA(256 * 4 * 4, 512)
        self.relu_fc1 = ReLUVector_CUDA()
        self.fc2 = FullyConnected_CUDA(512, 10)
        self.softmax = Softmax_CUDA()

# %% [markdown]
# ### **Train**

# %% [markdown]
# #### Hàm train

# %%
def train_cuda(model, train_data, train_labels, epochs=1, learning_rate=0.001,
                     mb_size=32, momentum=0.9, lr_decay_factor=0.5,
                     log_filename="training_log_cuda.csv", detail_log_filename="details_log_cuda.csv"):

    np.random.seed(0)
    cross_entropy = CrossEntropyLoss_CUDA()
    n_samples = train_data.shape[0]
    indices = np.arange(n_samples)

    best_train_acc = 0
    plateau_count = 0
    patience = 2

    for epoch in range(epochs):
        start_epoch = time.time()
        total_loss = 0.0
        correct = 0

        conv2d_time = relu_time = maxpool_time = flatten_time = fc_time = softmax_time = 0.0

        np.random.shuffle(indices)
        train_data_shuffled = train_data[indices]
        train_labels_shuffled = train_labels[indices]

        full_batch_count = n_samples // mb_size
        for i in range(full_batch_count):
            start = i * mb_size
            end = start + mb_size
            X_batch = train_data_shuffled[start:end]
            y_batch = train_labels_shuffled[start:end]

            for x_idx, (x, target) in enumerate(zip(X_batch, y_batch)):
                print(f"\n📌 Sample {i * mb_size + x_idx}")
                ## ====== FORWARD ======
                out = x
                for conv, relu in zip(model.block1.convs, model.block1.relus):
                    t0 = time.time(); out = conv.forward(out); t1 = time.time(); conv2d_time += t1 - t0
                    t0 = time.time(); out = relu.forward(out); t1 = time.time(); relu_time += t1 - t0
                t0 = time.time(); out = model.block1.pool.forward(out); t1 = time.time(); maxpool_time += t1 - t0

                for conv, relu in zip(model.block2.convs, model.block2.relus):
                    t0 = time.time(); out = conv.forward(out); t1 = time.time(); conv2d_time += t1 - t0
                    t0 = time.time(); out = relu.forward(out); t1 = time.time(); relu_time += t1 - t0
                t0 = time.time(); out = model.block2.pool.forward(out); t1 = time.time(); maxpool_time += t1 - t0

                for conv, relu in zip(model.block3.convs, model.block3.relus):
                    t0 = time.time(); out = conv.forward(out); t1 = time.time(); conv2d_time += t1 - t0
                    t0 = time.time(); out = relu.forward(out); t1 = time.time(); relu_time += t1 - t0
                t0 = time.time(); out = model.block3.pool.forward(out); t1 = time.time(); maxpool_time += t1 - t0

                t0 = time.time(); out = model.flatten.forward(out); t1 = time.time(); flatten_time += t1 - t0
                t0 = time.time(); out = model.fc1.forward(out); t1 = time.time(); fc_time += t1 - t0
                t0 = time.time(); out = model.relu_fc1.forward(out); t1 = time.time(); relu_time += t1 - t0
                t0 = time.time(); out = model.fc2.forward(out); t1 = time.time(); fc_time += t1 - t0
                t0 = time.time(); pred_probs = model.softmax.forward(out); t1 = time.time(); softmax_time += t1 - t0

                loss = cross_entropy.forward(pred_probs, target)
                total_loss += loss
                pred_idx = np.argmax(pred_probs)
                true_idx = np.argmax(target)

                if pred_idx == true_idx:
                    correct += 1
                    print(f"✔ Predict: {pred_idx}, True: {true_idx}")
                else:
                    print(f"❌ Predict: {pred_idx}, True: {true_idx}")

                ## ====== BACKWARD ======
                t0 = time.time(); grad = cross_entropy.backward(); t1 = time.time(); softmax_time += t1 - t0
                t0 = time.time(); grad = model.fc2.backward(grad); t1 = time.time(); fc_time += t1 - t0
                t0 = time.time(); grad = model.relu_fc1.backward(grad); t1 = time.time(); relu_time += t1 - t0
                t0 = time.time(); grad = model.fc1.backward(grad); t1 = time.time(); fc_time += t1 - t0
                t0 = time.time(); grad = model.flatten.backward(grad); t1 = time.time(); flatten_time += t1 - t0

                t0 = time.time(); grad = model.block3.pool.backward(grad); t1 = time.time(); maxpool_time += t1 - t0
                for conv, relu in zip(reversed(model.block3.convs), reversed(model.block3.relus)):
                    t0 = time.time(); grad = relu.backward(grad); t1 = time.time(); relu_time += t1 - t0
                    t0 = time.time(); grad = conv.backward(grad); t1 = time.time(); conv2d_time += t1 - t0

                t0 = time.time(); grad = model.block2.pool.backward(grad); t1 = time.time(); maxpool_time += t1 - t0
                for conv, relu in zip(reversed(model.block2.convs), reversed(model.block2.relus)):
                    t0 = time.time(); grad = relu.backward(grad); t1 = time.time(); relu_time += t1 - t0
                    t0 = time.time(); grad = conv.backward(grad); t1 = time.time(); conv2d_time += t1 - t0

                t0 = time.time(); grad = model.block1.pool.backward(grad); t1 = time.time(); maxpool_time += t1 - t0
                for conv, relu in zip(reversed(model.block1.convs), reversed(model.block1.relus)):
                    t0 = time.time(); grad = relu.backward(grad); t1 = time.time(); relu_time += t1 - t0
                    t0 = time.time(); grad = conv.backward(grad); t1 = time.time(); conv2d_time += t1 - t0

                ## ====== UPDATE ======
                model.fc2.step(learning_rate, momentum)
                model.fc1.step(learning_rate, momentum)
                model.block3.step(learning_rate, momentum)
                model.block2.step(learning_rate, momentum)
                model.block1.step(learning_rate, momentum)

        end_epoch = time.time()
        epoch_time = end_epoch - start_epoch
        accuracy = correct / (full_batch_count * mb_size)

        func.log_training_details(epoch, epochs, epoch_time, n_samples, total_loss / (full_batch_count * mb_size), accuracy, log_filename)
        func.log_details(f"Epoch_{epoch+1}", mb_size, conv2d_time, relu_time, maxpool_time, flatten_time, fc_time, softmax_time, detail_log_filename)

        print(f"Epoch {epoch+1}/{epochs} - Loss: {total_loss/(full_batch_count * mb_size):.4f} - Acc: {accuracy:.4f} - Time: {epoch_time:.2f}s")
        print(f"    Conv2D: {conv2d_time:.2f}s | ReLU: {relu_time:.2f}s | MaxPool: {maxpool_time:.2f}s | Flatten: {flatten_time:.2f}s | FC: {fc_time:.2f}s | Softmax: {softmax_time:.2f}s\n")

        # Learning rate scheduler
        if epoch == 0:
            best_train_acc = accuracy
            plateau_count = 0
        else:
            if accuracy > best_train_acc:
                best_train_acc = accuracy
                plateau_count = 0
            else:
                plateau_count += 1
                if plateau_count >= patience:
                    learning_rate *= lr_decay_factor
                    plateau_count = 0
                    print(f"⚠️  ReduceLROnPlateau: Learning rate reduced to {learning_rate:.6f}")

# %% [markdown]
# #### 10 ảnh, 1 epoch

# %%
model = SimpleCNN_CUDA()
train_cuda(
    model,
    X_train[:10],  # train thử 10 mẫu đầua
    y_train_onehot[:10],
    epochs=1,        # train thử 1 epoch
    learning_rate=0.001,
    momentum=0.9,
    lr_decay_factor=0.5,
    mb_size=2,
    log_filename="Data/log/training_log_cuda_ver4_op_10.csv",
    detail_log_filename="Data/log/details_log_cuda_ver4_op_10.csv"
)
# Out:
# 📌 Sample 0
# ❌ Predict: 1, True: 9
#
# 📌 Sample 1
# ❌ Predict: 9, True: 8
#
# 📌 Sample 2
# ❌ Predict: 9, True: 1
#
# 📌 Sample 3
# ❌ Predict: 9, True: 3
#
# 📌 Sample 4
# ✔ Predict: 9, True: 9
#
# 📌 Sample 5
# ❌ Predict: 9, True: 2
#
# 📌 Sample 6
# ❌ Predict: 9, True: 7
#
# 📌 Sample 7
# ❌ Predict: 9, True: 4
#
# 📌 Sample 8
# ❌ Predict: 9, True: 6
#
# 📌 Sample 9
# ❌ Predict: 9, True: 1
# Epoch 1/1 - Loss: 2.3207 - Acc: 0.1000 - Time: 2.28s
#     Conv2D: 1.31s | ReLU: 0.18s | MaxPool: 0.11s | Flatten: 0.02s | FC: 0.44s | Softmax: 0.00s

# %%
func.plot_details("Data/log/details_log_cuda_ver4_op_10.csv")

# %%
func.plot_compare_details_customized(
    "Data/log/details_log_cuda_ver4_op_10.csv",
    "Data/log/details_log_cuda_ver4_10.csv",
    "Numba op 1",
    "Numba"
)

# %% [markdown]
# #### 50000 ảnh, 1 epoch

# %%
model_2 = SimpleCNN_CUDA()
train_cuda(
    model_2,
    X_train,
    y_train_onehot,
    epochs=1,        # train thử 1 epoch
    learning_rate=0.001,
    momentum=0.9,
    lr_decay_factor=0.5,
    mb_size=64,
    log_filename="Data/log/training_log_cuda_ver4_50000_op_1.csv",
    detail_log_filename="Data/log/details_log_cuda_ver4_50000_op_1.csv"
)
# Out:
# 📌 Sample 0
# ❌ Predict: 9, True: 7
#
# 📌 Sample 1
# ❌ Predict: 9, True: 5
#
# 📌 Sample 2
# ❌ Predict: 7, True: 5
#
# 📌 Sample 3
# ❌ Predict: 5, True: 6
#
# 📌 Sample 4
# ✔ Predict: 5, True: 5
#
# 📌 Sample 5
# ❌ Predict: 5, True: 4
#
# 📌 Sample 6
# ❌ Predict: 5, True: 3
#
# 📌 Sample 7
# ❌ Predict: 5, True: 0
#
# 📌 Sample 8
# ❌ Predict: 5, True: 7
#
# 📌 Sample 9
# ❌ Predict: 5, True: 2
#
# 📌 Sample 10
# ✔ Predict: 5, True: 5
#
# 📌 Sample 11
# ❌ Predict: 5, True: 0
#
# 📌 Sample 12
# ❌ Predict: 5, True: 3
#
# 📌 Sample 13
# ❌ Predict: 5, True: 4
#
# 📌 Sample 14
# ❌ Predict: 5, True: 9
#
# 📌 Sample 15
# ❌ Predict: 5, True: 2
#
# 📌 Sample 16
# ❌ Predict: 5, True: 4
#
# 📌 Sample 17
# ❌ Predict: 5, True: 7
#
# 📌 Sample 18
# ❌ Predict: 5, True: 7
#
# 📌 Sample 19
# ✔ Predict: 5, True: 5
#
# 📌 Sample 20
# ✔ Predict: 5, True: 5
#
# 📌 Sample 21
# ❌ Predict: 5, True: 4
#
# 📌 Sample 22
# ❌ Predict: 5, True: 1
#
# 📌 Sample 23
# ❌ Predict: 5, True: 9
#
# 📌 Sample 24
# ❌ Predict: 5, True: 3
#
# 📌 Sample 25
# ❌ Predict: 5, True: 9
#
# 📌 Sample 26
# ❌ Predict: 5, True: 6
#
# 📌 Sample 27
# ❌ Predict: 5, True: 2
#
# 📌 Sample 28
# ❌ Predict: 5, True: 3
#
# 📌 Sample 29
# ✔ Predict: 5, True: 5
#
# 📌 Sample 30
# ✔ Predict: 5, True: 5
#
# 📌 Sample 31
# ❌ Predict: 5, True: 1
#
# 📌 Sample 32
# ✔ Predict: 5, True: 5
#
# 📌 Sample 33
# ❌ Predict: 5, True: 4
#
# 📌 Sample 34
# ❌ Predict: 5, True: 2
#
# 📌 Sample 35
# ❌ Predict: 5, True: 3
#
# 📌 Sample 36
# ❌ Predict: 5, True: 8
#
# 📌 Sample 37
# ❌ Predict: 5, True: 9
#
# 📌 Sample 38
# ✔ Predict: 5, True: 5
#
# 📌 Sample 39
# ❌ Predict: 5, True: 7
#
# 📌 Sample 40
# ❌ Predict: 5, True: 1
#
# 📌 Sample 41
# ❌ Predict: 5, True: 9
#
# 📌 Sample 42
# ❌ Predict: 5, True: 8
#
# 📌 Sample 43
# ❌ Predict: 5, True: 0
#
# 📌 Sample 44
# ❌ Predict: 5, True: 3
#
# 📌 Sample 45
# ❌ Predict: 5, True: 1
#
# 📌 Sample 46
# ❌ Predict: 5, True: 2
#
# 📌 Sample 47
# ❌ Predict: 5, True: 7
#
# 📌 Sample 48
# ❌ Predict: 5, True: 9
#
# 📌 Sample 49
# ❌ Predict: 5, True: 1
#
# 📌 Sample 50
# ❌ Predict: 5, True: 4
#
# 📌 Sample 51
# ❌ Predict: 5, True: 0
#
# 📌 Sample 52
# ❌ Predict: 5, True: 7
#
# 📌 Sample 53
# ❌ Predict: 5, True: 1
#
# 📌 Sample 54
# ❌ Predict: 5, True: 6
#
# 📌 Sample 55
# ✔ Predict: 9, True: 9
#
# 📌 Sample 56
# ✔ Predict: 9, True: 9
#
# 📌 Sample 57
# ❌ Predict: 9, True: 8
#
# 📌 Sample 58
# ❌ Predict: 9, True: 0
#
# 📌 Sample 59
# ❌ Predict: 9, True: 2
#
# 📌 Sample 60
# ❌ Predict: 9, True: 0
#
# 📌 Sample 61
# ❌ Predict: 9, True: 2
#
# 📌 Sample 62
# ❌ Predict: 9, True: 2
#
# 📌 Sample 63
# ❌ Predict: 9, True: 0
#
# 📌 Sample 64
# ❌ Predict: 9, True: 8
#
# 📌 Sample 65
# ❌ Predict: 9, True: 3
#
# 📌 Sample 66
# ❌ Predict: 9, True: 4
#
# 📌 Sample 67
# ❌ Predict: 9, True: 7
#
# 📌 Sample 68
# ❌ Predict: 9, True: 2
#
# 📌 Sample 69
# ❌ Predict: 9, True: 0
#
# 📌 Sample 70
# ❌ Predict: 9, True: 6
#
# 📌 Sample 71
# ❌ Predict: 9, True: 8
#
# 📌 Sample 72
# ❌ Predict: 9, True: 0
#
# 📌 Sample 73
# ❌ Predict: 9, True: 4
#
# 📌 Sample 74
# ❌ Predict: 9, True: 7
#
# 📌 Sample 75
# ❌ Predict: 9, True: 1
#
# 📌 Sample 76
# ✔ Predict: 9, True: 9
#
# 📌 Sample 77
# ❌ Predict: 9, True: 5
#
# 📌 Sample 78
# ❌ Predict: 9, True: 7
#
# 📌 Sample 79
# ❌ Predict: 9, True: 7
#
# 📌 Sample 80
# ❌ Predict: 9, True: 4
#
# 📌 Sample 81
# ❌ Predict: 9, True: 5
#
# 📌 Sample 82
# ✔ Predict: 9, True: 9
#
# 📌 Sample 83
# ✔ Predict: 9, True: 9
#
# 📌 Sample 84
# ❌ Predict: 9, True: 4
#
# 📌 Sample 85
# ❌ Predict: 9, True: 6
#
# 📌 Sample 86
# ❌ Predict: 9, True: 3
#
# 📌 Sample 87
# ❌ Predict: 9, True: 0
#
# 📌 Sample 88
# ❌ Predict: 9, True: 6
#
# 📌 Sample 89
# ❌ Predict: 9, True: 2
#
# 📌 Sample 90
# ✔ Predict: 9, True: 9
#
# 📌 Sample 91
# ❌ Predict: 9, True: 2
#
# 📌 Sample 92
# ❌ Predict: 9, True: 7
#
# 📌 Sample 93
# ❌ Predict: 9, True: 4
#
# 📌 Sample 94
# ❌ Predict: 9, True: 2
#
# 📌 Sample 95
# ❌ Predict: 9, True: 5
#
# 📌 Sample 96
# ❌ Predict: 9, True: 6
#
# 📌 Sample 97
# ❌ Predict: 9, True: 7
#
# 📌 Sample 98
# ❌ Predict: 9, True: 3
#
# 📌 Sample 99
# ❌ Predict: 9, True: 4
#
# 📌 Sample 100
# ❌ Predict: 9, True: 1
#
# 📌 Sample 101
# ❌ Predict: 9, True: 0
#
# 📌 Sample 102
# ❌ Predict: 9, True: 8
#
# 📌 Sample 103
# ❌ Predict: 9, True: 4
#
# 📌 Sample 104
# ❌ Predict: 9, True: 8
#
# 📌 Sample 105
# ❌ Predict: 9, True: 4
#
# 📌 Sample 106
# ❌ Predict: 9, True: 2
#
# 📌 Sample 107
# ✔ Predict: 9, True: 9
#
# 📌 Sample 108
# ❌ Predict: 9, True: 7
#
# 📌 Sample 109
# ❌ Predict: 9, True: 1
#
# 📌 Sample 110
# ✔ Predict: 9, True: 9
#
# 📌 Sample 111
# ✔ Predict: 9, True: 9
#
# 📌 Sample 112
# ❌ Predict: 9, True: 6
#
# 📌 Sample 113
# ❌ Predict: 9, True: 0
#
# 📌 Sample 114
# ❌ Predict: 9, True: 1
#
# 📌 Sample 115
# ❌ Predict: 9, True: 8
#
# 📌 Sample 116
# ❌ Predict: 9, True: 3
#
# 📌 Sample 117
# ❌ Predict: 9, True: 1
#
# 📌 Sample 118
# ❌ Predict: 9, True: 7
#
# 📌 Sample 119
# ❌ Predict: 9, True: 0
#
# 📌 Sample 120
# ❌ Predict: 9, True: 3
#
# 📌 Sample 121
# ❌ Predict: 9, True: 0
#
# 📌 Sample 122
# ❌ Predict: 9, True: 0
#
# 📌 Sample 123
# ❌ Predict: 9, True: 3
#
# 📌 Sample 124
# ❌ Predict: 9, True: 6
#
# 📌 Sample 125
# ❌ Predict: 9, True: 8
#
# 📌 Sample 126
# ❌ Predict: 9, True: 0
#
# 📌 Sample 127
# ❌ Predict: 9, True: 5
#
# 📌 Sample 128
# ❌ Predict: 9, True: 7
#
# 📌 Sample 129
# ❌ Predict: 9, True: 7
#
# 📌 Sample 130
# ❌ Predict: 9, True: 5
#
# 📌 Sample 131
# ❌ Predict: 9, True: 6
#
# 📌 Sample 132
# ❌ Predict: 9, True: 7
#
# 📌 Sample 133
# ✔ Predict: 0, True: 0
#
# 📌 Sample 134
# ✔ Predict: 0, True: 0
#
# 📌 Sample 135
# ❌ Predict: 0, True: 9
#
# 📌 Sample 136
# ❌ Predict: 0, True: 7
#
# 📌 Sample 137
# ❌ Predict: 0, True: 4
#
# 📌 Sample 138
# ❌ Predict: 0, True: 3
#
# 📌 Sample 139
# ❌ Predict: 0, True: 1
#
# 📌 Sample 140
# ❌ Predict: 0, True: 1
#
# 📌 Sample 141
# ❌ Predict: 0, True: 5
#
# 📌 Sample 142
# ❌ Predict: 0, True: 3
#
# 📌 Sample 143
# ❌ Predict: 0, True: 4
#
# 📌 Sample 144
# ❌ Predict: 0, True: 2
#
# 📌 Sample 145
# ❌ Predict: 0, True: 9
#
# 📌 Sample 146
# ❌ Predict: 0, True: 2
#
# 📌 Sample 147
# ❌ Predict: 0, True: 8
#
# 📌 Sample 148
# ❌ Predict: 0, True: 6
#
# 📌 Sample 149
# ❌ Predict: 0, True: 6
#
# 📌 Sample 150
# ✔ Predict: 0, True: 0
#
# 📌 Sample 151
# ❌ Predict: 0, True: 2
#
# 📌 Sample 152
# ❌ Predict: 0, True: 7
#
# 📌 Sample 153
# ❌ Predict: 0, True: 6
#
# 📌 Sample 154
# ❌ Predict: 0, True: 1
#
# 📌 Sample 155
# ❌ Predict: 0, True: 1
#
# 📌 Sample 156
# ✔ Predict: 0, True: 0
#
# 📌 Sample 157
# ✔ Predict: 0, True: 0
#
# 📌 Sample 158
# ❌ Predict: 0, True: 8
#
# 📌 Sample 159
# ❌ Predict: 0, True: 6
#
# 📌 Sample 160
# ❌ Predict: 0, True: 2
#
# 📌 Sample 161
# ❌ Predict: 0, True: 8
#
# 📌 Sample 162
# ❌ Predict: 0, True: 1
#
# 📌 Sample 163
# ❌ Predict: 0, True: 6
#
# 📌 Sample 164
# ❌ Predict: 0, True: 5
#
# 📌 Sample 165
# ❌ Predict: 0, True: 2
#
# 📌 Sample 166
# ❌ Predict: 0, True: 6
#
# 📌 Sample 167
# ❌ Predict: 0, True: 8
#
# 📌 Sample 168
# ❌ Predict: 0, True: 9
#
# 📌 Sample 169
# ❌ Predict: 0, True: 7
#
# 📌 Sample 170
# ❌ Predict: 0, True: 7
#
# 📌 Sample 171
# ❌ Predict: 0, True: 6
#
# 📌 Sample 172
# ❌ Predict: 0, True: 1
#
# 📌 Sample 173
# ❌ Predict: 0, True: 6
#
# 📌 Sample 174
# ❌ Predict: 0, True: 6
#
# 📌 Sample 175
# ❌ Predict: 0, True: 2
#
# 📌 Sample 176
# ❌ Predict: 0, True: 4
#
# 📌 Sample 177
# ❌ Predict: 0, True: 2
#
# 📌 Sample 178
# ❌ Predict: 0, True: 3
#
# 📌 Sample 179
# ❌ Predict: 0, True: 2
#
# 📌 Sample 180
# ❌ Predict: 0, True: 7
#
# 📌 Sample 181
# ❌ Predict: 0, True: 7
#
# 📌 Sample 182
# ❌ Predict: 0, True: 6
#
# 📌 Sample 183
# ❌ Predict: 0, True: 4
#
# 📌 Sample 184
# ❌ Predict: 0, True: 3
#
# 📌 Sample 185
# ❌ Predict: 0, True: 9
#
# 📌 Sample 186
# ❌ Predict: 0, True: 3
#
# 📌 Sample 187
# ❌ Predict: 0, True: 7
#
# 📌 Sample 188
# ❌ Predict: 7, True: 1
#
# 📌 Sample 189
# ❌ Predict: 7, True: 2
#
# 📌 Sample 190
# ❌ Predict: 7, True: 4
#
# 📌 Sample 191
# ❌ Predict: 7, True: 5
#
# 📌 Sample 192
# ❌ Predict: 7, True: 1
#
# 📌 Sample 193
# ✔ Predict: 7, True: 7
#
# 📌 Sample 194
# ❌ Predict: 7, True: 0
#
# 📌 Sample 195
# ❌ Predict: 7, True: 0
#
# 📌 Sample 196
# ❌ Predict: 7, True: 1
#
# 📌 Sample 197
# ❌ Predict: 7, True: 1
#
# 📌 Sample 198
# ❌ Predict: 7, True: 5
#
# 📌 Sample 199
# ❌ Predict: 7, True: 9
#
# 📌 Sample 200
# ❌ Predict: 7, True: 2
#
# 📌 Sample 201
# ❌ Predict: 7, True: 1
#
# 📌 Sample 202
# ❌ Predict: 7, True: 8
#
# 📌 Sample 203
# ✔ Predict: 7, True: 7
#
# 📌 Sample 204
# ❌ Predict: 7, True: 9
#
# 📌 Sample 205
# ❌ Predict: 7, True: 5
#
# 📌 Sample 206
# ❌ Predict: 7, True: 5
#
# 📌 Sample 207
# ❌ Predict: 7, True: 0
#
# 📌 Sample 208
# ❌ Predict: 7, True: 6
#
# 📌 Sample 209
# ❌ Predict: 7, True: 3
#
# 📌 Sample 210
# ❌ Predict: 7, True: 2
#
# 📌 Sample 211
# ❌ Predict: 7, True: 0
#
# 📌 Sample 212
# ❌ Predict: 7, True: 2
#
# 📌 Sample 213
# ❌ Predict: 7, True: 6
#
# 📌 Sample 214
# ❌ Predict: 7, True: 0
#
# 📌 Sample 215
# ❌ Predict: 7, True: 6
#
# 📌 Sample 216
# ❌ Predict: 7, True: 2
#
# 📌 Sample 217
# ❌ Predict: 7, True: 5
#
# 📌 Sample 218
# ❌ Predict: 7, True: 6
#
# 📌 Sample 219
# ❌ Predict: 7, True: 6
#
# 📌 Sample 220
# ❌ Predict: 7, True: 1
#
# 📌 Sample 221
# ❌ Predict: 7, True: 9
#
# 📌 Sample 222
# ❌ Predict: 0, True: 2
#
# 📌 Sample 223
# ❌ Predict: 7, True: 1
#
# 📌 Sample 224
# ❌ Predict: 0, True: 9
#
# 📌 Sample 225
# ❌ Predict: 0, True: 5
#
# 📌 Sample 226
# ❌ Predict: 0, True: 8
#
# 📌 Sample 227
# ❌ Predict: 0, True: 8
#
# 📌 Sample 228
# ❌ Predict: 0, True: 5
#
# 📌 Sample 229
# ✔ Predict: 2, True: 2
#
# 📌 Sample 230
# ❌ Predict: 2, True: 1
#
# 📌 Sample 231
# ❌ Predict: 2, True: 7
#
# 📌 Sample 232
# ❌ Predict: 2, True: 9
#
# 📌 Sample 233
# ❌ Predict: 2, True: 5
#
# 📌 Sample 234
# ❌ Predict: 2, True: 9
#
# 📌 Sample 235
# ❌ Predict: 2, True: 0
#
# 📌 Sample 236
# ❌ Predict: 2, True: 0
#
# 📌 Sample 237
# ❌ Predict: 2, True: 3
#
# 📌 Sample 238
# ❌ Predict: 2, True: 1
#
# 📌 Sample 239
# ❌ Predict: 1, True: 9
#
# 📌 Sample 240
# ❌ Predict: 2, True: 7
#
# 📌 Sample 241
# ❌ Predict: 1, True: 9
#
# 📌 Sample 242
# ❌ Predict: 1, True: 6
#
# 📌 Sample 243
# ❌ Predict: 1, True: 2
#
# 📌 Sample 244
# ❌ Predict: 1, True: 8
#
# 📌 Sample 245
# ❌ Predict: 1, True: 0
#
# 📌 Sample 246
# ❌ Predict: 1, True: 5
#
# 📌 Sample 247
# ❌ Predict: 1, True: 4
#
# 📌 Sample 248
# ❌ Predict: 1, True: 0
#
# 📌 Sample 249
# ❌ Predict: 9, True: 1
#
# 📌 Sample 250
# ❌ Predict: 0, True: 8
#
# 📌 Sample 251
# ❌ Predict: 0, True: 4
#
# 📌 Sample 252
# ❌ Predict: 0, True: 4
#
# 📌 Sample 253
# ❌ Predict: 0, True: 8
#
# 📌 Sample 254
# ❌ Predict: 0, True: 1
#
# 📌 Sample 255
# ❌ Predict: 1, True: 3
#
# 📌 Sample 256
# ✔ Predict: 1, True: 1
#
# 📌 Sample 257
# ❌ Predict: 1, True: 2
#
# 📌 Sample 258
# ❌ Predict: 1, True: 9
#
# 📌 Sample 259
# ❌ Predict: 1, True: 3
#
# 📌 Sample 260
# ❌ Predict: 1, True: 5
#
# 📌 Sample 261
# ❌ Predict: 1, True: 0
#
# 📌 Sample 262
# ❌ Predict: 1, True: 7
#
# 📌 Sample 263
# ❌ Predict: 1, True: 7
#
# 📌 Sample 264
# ❌ Predict: 1, True: 7
#
# 📌 Sample 265
# ❌ Predict: 1, True: 3
#
# 📌 Sample 266
# ✔ Predict: 1, True: 1
#
# 📌 Sample 267
# ❌ Predict: 1, True: 8
#
# 📌 Sample 268
# ❌ Predict: 1, True: 3
#
# 📌 Sample 269
# ❌ Predict: 1, True: 3
#
# 📌 Sample 270
# ❌ Predict: 1, True: 7
#
# 📌 Sample 271
# ❌ Predict: 1, True: 4
#
# 📌 Sample 272
# ❌ Predict: 1, True: 0
#
# 📌 Sample 273
# ❌ Predict: 1, True: 0
#
# 📌 Sample 274
# ❌ Predict: 1, True: 6
#
# 📌 Sample 275
# ❌ Predict: 1, True: 0
#
# 📌 Sample 276
# ❌ Predict: 1, True: 4
#
# 📌 Sample 277
# ❌ Predict: 1, True: 3
#
# 📌 Sample 278
# ❌ Predict: 1, True: 4
#
# 📌 Sample 279
# ❌ Predict: 1, True: 2
#
# 📌 Sample 280
# ❌ Predict: 1, True: 6
#
# 📌 Sample 281
# ❌ Predict: 1, True: 3
#
# 📌 Sample 282
# ❌ Predict: 0, True: 1
#
# 📌 Sample 283
# ❌ Predict: 0, True: 6
#
# 📌 Sample 284
# ❌ Predict: 0, True: 2
#
# 📌 Sample 285
# ❌ Predict: 0, True: 1
#
# 📌 Sample 286
# ❌ Predict: 0, True: 5
#
# 📌 Sample 287
# ❌ Predict: 0, True: 7
#
# 📌 Sample 288
# ❌ Predict: 0, True: 9
#
# 📌 Sample 289
# ❌ Predict: 0, True: 7
#
# 📌 Sample 290
# ✔ Predict: 0, True: 0
#
# 📌 Sample 291
# ❌ Predict: 0, True: 3
#
# 📌 Sample 292
# ❌ Predict: 1, True: 9
#
# 📌 Sample 293
# ❌ Predict: 0, True: 6
#
# 📌 Sample 294
# ❌ Predict: 0, True: 5
#
# 📌 Sample 295
# ❌ Predict: 0, True: 9
#
# 📌 Sample 296
# ❌ Predict: 0, True: 1
#
# 📌 Sample 297
# ❌ Predict: 0, True: 4
#
# 📌 Sample 298
# ❌ Predict: 1, True: 4
#
# 📌 Sample 299
# ❌ Predict: 1, True: 7
#
# 📌 Sample 300
# ❌ Predict: 1, True: 7
#
# 📌 Sample 301
# ❌ Predict: 1, True: 7
#
# 📌 Sample 302
# ❌ Predict: 1, True: 3
#
# 📌 Sample 303
# ❌ Predict: 1, True: 7
#
# 📌 Sample 304
# ❌ Predict: 1, True: 9
#
# 📌 Sample 305
# ❌ Predict: 1, True: 3
#
# 📌 Sample 306
# ❌ Predict: 1, True: 8
#
# 📌 Sample 307
# ❌ Predict: 1, True: 4
#
# 📌 Sample 308
# ❌ Predict: 7, True: 5
#
# 📌 Sample 309
# ❌ Predict: 7, True: 3
#
# 📌 Sample 310
# ❌ Predict: 7, True: 6
#
# 📌 Sample 311
# ✔ Predict: 7, True: 7
#
# 📌 Sample 312
# ✔ Predict: 7, True: 7
#
# 📌 Sample 313
# ❌ Predict: 7, True: 1
#
# 📌 Sample 314
# ✔ Predict: 7, True: 7
#
# 📌 Sample 315
# ❌ Predict: 7, True: 3
#
# 📌 Sample 316
# ❌ Predict: 7, True: 2
#
# 📌 Sample 317
# ❌ Predict: 7, True: 6
#
# 📌 Sample 318
# ❌ Predict: 7, True: 6
#
# 📌 Sample 319
# ✔ Predict: 7, True: 7
#
# 📌 Sample 320
# ❌ Predict: 7, True: 4
#
# 📌 Sample 321
# ❌ Predict: 7, True: 4
#
# 📌 Sample 322
# ❌ Predict: 7, True: 6
#
# 📌 Sample 323
# ✔ Predict: 7, True: 7
#
# 📌 Sample 324
# ❌ Predict: 7, True: 0
#
# 📌 Sample 325
# ❌ Predict: 7, True: 1
#
# 📌 Sample 326
# ❌ Predict: 7, True: 8
#
# 📌 Sample 327
# ❌ Predict: 7, True: 6
#
# 📌 Sample 328
# ❌ Predict: 7, True: 8
#
# 📌 Sample 329
# ✔ Predict: 7, True: 7
#
# 📌 Sample 330
# ❌ Predict: 7, True: 3
#
# 📌 Sample 331
# ❌ Predict: 7, True: 0
#
# 📌 Sample 332
# ❌ Predict: 7, True: 8
#
# 📌 Sample 333
# ❌ Predict: 7, True: 1
#
# 📌 Sample 334
# ❌ Predict: 7, True: 8
#
# 📌 Sample 335
# ❌ Predict: 7, True: 8
#
# 📌 Sample 336
# ❌ Predict: 7, True: 8
#
# 📌 Sample 337
# ❌ Predict: 7, True: 3
#
# 📌 Sample 338
# ❌ Predict: 7, True: 5
#
# 📌 Sample 339
# ❌ Predict: 7, True: 8
#
# 📌 Sample 340
# ❌ Predict: 7, True: 5
#
# 📌 Sample 341
# ❌ Predict: 7, True: 4
#
# 📌 Sample 342
# ❌ Predict: 7, True: 9
#
# 📌 Sample 343
# ❌ Predict: 7, True: 0
#
# 📌 Sample 344
# ❌ Predict: 7, True: 5
#
# 📌 Sample 345
# ❌ Predict: 7, True: 6
#
# 📌 Sample 346
# ❌ Predict: 7, True: 6
#
# 📌 Sample 347
# ❌ Predict: 7, True: 5
#
# 📌 Sample 348
# ❌ Predict: 7, True: 1
#
# 📌 Sample 349
# ❌ Predict: 7, True: 1
#
# 📌 Sample 350
# ❌ Predict: 7, True: 4
#
# 📌 Sample 351
# ❌ Predict: 7, True: 2
#
# 📌 Sample 352
# ❌ Predict: 7, True: 4
#
# 📌 Sample 353
# ❌ Predict: 7, True: 3
#
# 📌 Sample 354
# ❌ Predict: 7, True: 3
#
# 📌 Sample 355
# ❌ Predict: 7, True: 5
#
# 📌 Sample 356
# ❌ Predict: 7, True: 9
#
# 📌 Sample 357
# ❌ Predict: 7, True: 4
#
# 📌 Sample 358
# ❌ Predict: 7, True: 4
#
# 📌 Sample 359
# ❌ Predict: 7, True: 0
#
# 📌 Sample 360
# ❌ Predict: 7, True: 2
#
# 📌 Sample 361
# ❌ Predict: 7, True: 1
#
# 📌 Sample 362
# ❌ Predict: 7, True: 5
#
# 📌 Sample 363
# ❌ Predict: 7, True: 9
#
# 📌 Sample 364
# ❌ Predict: 7, True: 6
#
# 📌 Sample 365
# ❌ Predict: 7, True: 3
#
# 📌 Sample 366
# ❌ Predict: 7, True: 8
#
# 📌 Sample 367
# ❌ Predict: 7, True: 4
#
# 📌 Sample 368
# ❌ Predict: 7, True: 5
#
# 📌 Sample 369
# ❌ Predict: 7, True: 0
#
# 📌 Sample 370
# ❌ Predict: 7, True: 9
#
# 📌 Sample 371
# ❌ Predict: 7, True: 5
#
# 📌 Sample 372
# ❌ Predict: 7, True: 2
#
# 📌 Sample 373
# ❌ Predict: 7, True: 8
#
# 📌 Sample 374
# ❌ Predict: 7, True: 1
#
# 📌 Sample 375
# ❌ Predict: 7, True: 8
#
# 📌 Sample 376
# ❌ Predict: 7, True: 1
#
# 📌 Sample 377
# ❌ Predict: 7, True: 3
#
# 📌 Sample 378
# ❌ Predict: 7, True: 6
#
# 📌 Sample 379
# ❌ Predict: 7, True: 6
#
# 📌 Sample 380
# ❌ Predict: 7, True: 3
#
# 📌 Sample 381
# ❌ Predict: 7, True: 5
#
# 📌 Sample 382
# ❌ Predict: 7, True: 4
#
# 📌 Sample 383
# ❌ Predict: 7, True: 5
#
# 📌 Sample 384
# ✔ Predict: 7, True: 7
#
# 📌 Sample 385
# ❌ Predict: 7, True: 4
#
# 📌 Sample 386
# ❌ Predict: 7, True: 8
#
# 📌 Sample 387
# ❌ Predict: 7, True: 8
#
# 📌 Sample 388
# ❌ Predict: 7, True: 8
#
# 📌 Sample 389
# ❌ Predict: 7, True: 6
#
# 📌 Sample 390
# ❌ Predict: 7, True: 2
#
# 📌 Sample 391
# ❌ Predict: 7, True: 1
#
# 📌 Sample 392
# ✔ Predict: 7, True: 7
#
# 📌 Sample 393
# ❌ Predict: 7, True: 0
#
# 📌 Sample 394
# ❌ Predict: 7, True: 4
#
# 📌 Sample 395
# ❌ Predict: 7, True: 3
#
# 📌 Sample 396
# ❌ Predict: 7, True: 9
#
# 📌 Sample 397
# ❌ Predict: 7, True: 2
#
# 📌 Sample 398
# ❌ Predict: 7, True: 5
#
# 📌 Sample 399
# ✔ Predict: 7, True: 7
#
# 📌 Sample 400
# ❌ Predict: 7, True: 3
#
# 📌 Sample 401
# ❌ Predict: 7, True: 8
#
# 📌 Sample 402
# ❌ Predict: 7, True: 3
#
# 📌 Sample 403
# ❌ Predict: 7, True: 5
#
# 📌 Sample 404
# ❌ Predict: 7, True: 5
#
# 📌 Sample 405
# ❌ Predict: 7, True: 8
#
# 📌 Sample 406
# ❌ Predict: 7, True: 2
#
# 📌 Sample 407
# ❌ Predict: 7, True: 6
#
# 📌 Sample 408
# ❌ Predict: 7, True: 9
#
# 📌 Sample 409
# ❌ Predict: 7, True: 9
#
# 📌 Sample 410
# ❌ Predict: 7, True: 6
#
# 📌 Sample 411
# ❌ Predict: 7, True: 1
#
# 📌 Sample 412
# ❌ Predict: 7, True: 5
#
# 📌 Sample 413
# ❌ Predict: 7, True: 4
#
# 📌 Sample 414
# ❌ Predict: 7, True: 9
#
# 📌 Sample 415
# ❌ Predict: 7, True: 5
#
# 📌 Sample 416
# ❌ Predict: 7, True: 2
#
# 📌 Sample 417
# ✔ Predict: 7, True: 7
#
# 📌 Sample 418
# ❌ Predict: 7, True: 5
#
# 📌 Sample 419
# ❌ Predict: 7, True: 1
#
# 📌 Sample 420
# ❌ Predict: 7, True: 6
#
# 📌 Sample 421
# ❌ Predict: 7, True: 0
#
# 📌 Sample 422
# ❌ Predict: 7, True: 4
#
# 📌 Sample 423
# ❌ Predict: 7, True: 3
#
# 📌 Sample 424
# ✔ Predict: 7, True: 7
#
# 📌 Sample 425
# ❌ Predict: 7, True: 5
#
# 📌 Sample 426
# ❌ Predict: 7, True: 2
#
# 📌 Sample 427
# ❌ Predict: 7, True: 4
#
# 📌 Sample 428
# ❌ Predict: 7, True: 9
#
# 📌 Sample 429
# ❌ Predict: 7, True: 0
#
# 📌 Sample 430
# ❌ Predict: 5, True: 0
#
# 📌 Sample 431
# ❌ Predict: 7, True: 0
#
# 📌 Sample 432
# ❌ Predict: 7, True: 8
#
# 📌 Sample 433
# ❌ Predict: 7, True: 0
#
# 📌 Sample 434
# ❌ Predict: 7, True: 9
#
# 📌 Sample 435
# ❌ Predict: 7, True: 1
#
# 📌 Sample 436
# ❌ Predict: 7, True: 8
#
# 📌 Sample 437
# ❌ Predict: 7, True: 6
#
# 📌 Sample 438
# ✔ Predict: 7, True: 7
#
# 📌 Sample 439
# ❌ Predict: 7, True: 2
#
# 📌 Sample 440
# ❌ Predict: 7, True: 6
#
# 📌 Sample 441
# ❌ Predict: 7, True: 6
#
# 📌 Sample 442
# ❌ Predict: 7, True: 2
#
# 📌 Sample 443
# ❌ Predict: 7, True: 1
#
# 📌 Sample 444
# ❌ Predict: 7, True: 8
#
# 📌 Sample 445
# ❌ Predict: 7, True: 9
#
# 📌 Sample 446
# ❌ Predict: 7, True: 0
#
# 📌 Sample 447
# ✔ Predict: 7, True: 7
#
# 📌 Sample 448
# ❌ Predict: 7, True: 5
#
# 📌 Sample 449
# ✔ Predict: 7, True: 7
#
# 📌 Sample 450
# ❌ Predict: 7, True: 2
#
# 📌 Sample 451
# ❌ Predict: 7, True: 2
#
# 📌 Sample 452
# ✔ Predict: 7, True: 7
#
# 📌 Sample 453
# ❌ Predict: 7, True: 6
#
# 📌 Sample 454
# ❌ Predict: 7, True: 4
#
# 📌 Sample 455
# ❌ Predict: 7, True: 8
#
# 📌 Sample 456
# ❌ Predict: 7, True: 3
#
# 📌 Sample 457
# ❌ Predict: 7, True: 5
#
# 📌 Sample 458
# ❌ Predict: 7, True: 0
#
# 📌 Sample 459
# ❌ Predict: 7, True: 8
#
# 📌 Sample 460
# ❌ Predict: 7, True: 0
#
# 📌 Sample 461
# ❌ Predict: 7, True: 8
#
# 📌 Sample 462
# ❌ Predict: 7, True: 2
#
# 📌 Sample 463
# ❌ Predict: 7, True: 3
#
# 📌 Sample 464
# ❌ Predict: 7, True: 4
#
# 📌 Sample 465
# ❌ Predict: 7, True: 2
#
# 📌 Sample 466
# ❌ Predict: 7, True: 4
#
# 📌 Sample 467
# ❌ Predict: 7, True: 6
#
# 📌 Sample 468
# ❌ Predict: 7, True: 1
#
# 📌 Sample 469
# ❌ Predict: 7, True: 2
#
# 📌 Sample 470
# ❌ Predict: 7, True: 9
#
# 📌 Sample 471
# ❌ Predict: 7, True: 1
#
# 📌 Sample 472
# ❌ Predict: 7, True: 6
#
# 📌 Sample 473
# ❌ Predict: 7, True: 3
#
# 📌 Sample 474
# ❌ Predict: 7, True: 6
#
# 📌 Sample 475
# ❌ Predict: 7, True: 8
#
# 📌 Sample 476
# ❌ Predict: 7, True: 2
#
# 📌 Sample 477
# ❌ Predict: 7, True: 3
#
# 📌 Sample 478
# ✔ Predict: 7, True: 7
#
# 📌 Sample 479
# ❌ Predict: 7, True: 4
#
# 📌 Sample 480
# ❌ Predict: 6, True: 4
#
# 📌 Sample 481
# ❌ Predict: 6, True: 2
#
# 📌 Sample 482
# ❌ Predict: 6, True: 4
#
# 📌 Sample 483
# ❌ Predict: 6, True: 8
#
# 📌 Sample 484
# ❌ Predict: 7, True: 3
#
# 📌 Sample 485
# ❌ Predict: 6, True: 7
#
# 📌 Sample 486
# ❌ Predict: 6, True: 0
#
# 📌 Sample 487
# ❌ Predict: 6, True: 0
#
# 📌 Sample 488
# ✔ Predict: 7, True: 7
#
# 📌 Sample 489
# ❌ Predict: 7, True: 1
#
# 📌 Sample 490
# ✔ Predict: 7, True: 7
#
# 📌 Sample 491
# ❌ Predict: 7, True: 4
#
# 📌 Sample 492
# ❌ Predict: 7, True: 4
#
# 📌 Sample 493
# ❌ Predict: 7, True: 6
#
# 📌 Sample 494
# ❌ Predict: 7, True: 5
#
# 📌 Sample 495
# ❌ Predict: 7, True: 5
#
# 📌 Sample 496
# ❌ Predict: 7, True: 6
#
# 📌 Sample 497
# ❌ Predict: 7, True: 4
#
# 📌 Sample 498
# ❌ Predict: 7, True: 9
#
# 📌 Sample 499
# ❌ Predict: 7, True: 1
#
# 📌 Sample 500
# ❌ Predict: 7, True: 1
#
# 📌 Sample 501
# ❌ Predict: 7, True: 4
#
# 📌 Sample 502
# ✔ Predict: 7, True: 7
#
# 📌 Sample 503
# ✔ Predict: 7, True: 7
#
# 📌 Sample 504
# ❌ Predict: 7, True: 8
#
# 📌 Sample 505
# ❌ Predict: 7, True: 5
#
# 📌 Sample 506
# ❌ Predict: 7, True: 0
#
# 📌 Sample 507
# ❌ Predict: 7, True: 3
#
# 📌 Sample 508
# ❌ Predict: 7, True: 4
#
# 📌 Sample 509
# ❌ Predict: 7, True: 8
#
# 📌 Sample 510
# ❌ Predict: 7, True: 6
#
# 📌 Sample 511
# ❌ Predict: 7, True: 6
#
# 📌 Sample 512
# ❌ Predict: 7, True: 0
#
# 📌 Sample 513
# ❌ Predict: 7, True: 1
#
# 📌 Sample 514
# ❌ Predict: 7, True: 3
#
# 📌 Sample 515
# ❌ Predict: 7, True: 2
#
# 📌 Sample 516
# ❌ Predict: 7, True: 5
#
# 📌 Sample 517
# ❌ Predict: 7, True: 5
#
# 📌 Sample 518
# ❌ Predict: 7, True: 9
#
# 📌 Sample 519
# ❌ Predict: 7, True: 2
#
# 📌 Sample 520
# ❌ Predict: 7, True: 0
#
# 📌 Sample 521
# ✔ Predict: 7, True: 7
#
# 📌 Sample 522
# ❌ Predict: 7, True: 1
#
# 📌 Sample 523
# ✔ Predict: 7, True: 7
#
# 📌 Sample 524
# ❌ Predict: 7, True: 6
#
# 📌 Sample 525
# ❌ Predict: 7, True: 4
#
# 📌 Sample 526
# ❌ Predict: 7, True: 3
#
# 📌 Sample 527
# ❌ Predict: 7, True: 6
#
# 📌 Sample 528
# ❌ Predict: 7, True: 3
#
# 📌 Sample 529
# ❌ Predict: 7, True: 1
#
# 📌 Sample 530
# ✔ Predict: 7, True: 7
#
# 📌 Sample 531
# ❌ Predict: 7, True: 0
#
# 📌 Sample 532
# ❌ Predict: 7, True: 6
#
# 📌 Sample 533
# ✔ Predict: 7, True: 7
#
# 📌 Sample 534
# ❌ Predict: 7, True: 3
#
# 📌 Sample 535
# ❌ Predict: 7, True: 8
#
# 📌 Sample 536
# ❌ Predict: 7, True: 2
#
# 📌 Sample 537
# ❌ Predict: 7, True: 1
#
# 📌 Sample 538
# ❌ Predict: 7, True: 6
#
# 📌 Sample 539
# ❌ Predict: 7, True: 3
#
# 📌 Sample 540
# ❌ Predict: 7, True: 5
#
# 📌 Sample 541
# ❌ Predict: 7, True: 1
#
# 📌 Sample 542
# ❌ Predict: 7, True: 5
#
# 📌 Sample 543
# ❌ Predict: 7, True: 0
#
# 📌 Sample 544
# ❌ Predict: 7, True: 1
#
# 📌 Sample 545
# ❌ Predict: 7, True: 1
#
# 📌 Sample 546
# ❌ Predict: 7, True: 8
#
# 📌 Sample 547
# ❌ Predict: 7, True: 9
#
# 📌 Sample 548
# ❌ Predict: 7, True: 4
#
# 📌 Sample 549
# ❌ Predict: 7, True: 0
#
# 📌 Sample 550
# ❌ Predict: 7, True: 1
#
# 📌 Sample 551
# ❌ Predict: 7, True: 0
#
# 📌 Sample 552
# ❌ Predict: 7, True: 9
#
# 📌 Sample 553
# ✔ Predict: 7, True: 7
#
# 📌 Sample 554
# ❌ Predict: 7, True: 9
#
# 📌 Sample 555
# ❌ Predict: 7, True: 5
#
# 📌 Sample 556
# ❌ Predict: 7, True: 5
#
# 📌 Sample 557
# ❌ Predict: 1, True: 0
#
# 📌 Sample 558
# ❌ Predict: 7, True: 5
#
# 📌 Sample 559
# ❌ Predict: 1, True: 8
#
# 📌 Sample 560
# ❌ Predict: 7, True: 2
#
# 📌 Sample 561
# ❌ Predict: 7, True: 5
#
# 📌 Sample 562
# ❌ Predict: 1, True: 9
#
# 📌 Sample 563
# ❌ Predict: 7, True: 8
#
# 📌 Sample 564
# ❌ Predict: 1, True: 0
#
# 📌 Sample 565
# ❌ Predict: 7, True: 5
#
# 📌 Sample 566
# ❌ Predict: 1, True: 0
#
# 📌 Sample 567
# ❌ Predict: 7, True: 2
#
# 📌 Sample 568
# ❌ Predict: 7, True: 4
#
# 📌 Sample 569
# ❌ Predict: 1, True: 4
#
# 📌 Sample 570
# ❌ Predict: 0, True: 8
#
# 📌 Sample 571
# ✔ Predict: 0, True: 0
#
# 📌 Sample 572
# ❌ Predict: 0, True: 8
#
# 📌 Sample 573
# ❌ Predict: 0, True: 9
#
# 📌 Sample 574
# ❌ Predict: 0, True: 1
#
# 📌 Sample 575
# ❌ Predict: 0, True: 4
#
# 📌 Sample 576
# ❌ Predict: 0, True: 3
#
# 📌 Sample 577
# ❌ Predict: 0, True: 8
#
# 📌 Sample 578
# ❌ Predict: 0, True: 9
#
# 📌 Sample 579
# ❌ Predict: 0, True: 6
#
# 📌 Sample 580
# ✔ Predict: 0, True: 0
#
# 📌 Sample 581
# ❌ Predict: 0, True: 8
#
# 📌 Sample 582
# ❌ Predict: 0, True: 3
#
# 📌 Sample 583
# ❌ Predict: 0, True: 7
#
# 📌 Sample 584
# ❌ Predict: 0, True: 3
#
# 📌 Sample 585
# ❌ Predict: 0, True: 2
#
# 📌 Sample 586
# ❌ Predict: 0, True: 9
#
# 📌 Sample 587
# ❌ Predict: 0, True: 6
#
# 📌 Sample 588
# ❌ Predict: 0, True: 4
#
# 📌 Sample 589
# ✔ Predict: 0, True: 0
#
# 📌 Sample 590
# ❌ Predict: 0, True: 2
#
# 📌 Sample 591
# ❌ Predict: 0, True: 5
#
# 📌 Sample 592
# ❌ Predict: 0, True: 1
#
# 📌 Sample 593
# ❌ Predict: 0, True: 4
#
# 📌 Sample 594
# ❌ Predict: 0, True: 1
#
# 📌 Sample 595
# ❌ Predict: 0, True: 3
#
# 📌 Sample 596
# ❌ Predict: 0, True: 2
#
# 📌 Sample 597
# ❌ Predict: 0, True: 5
#
# 📌 Sample 598
# ❌ Predict: 0, True: 1
#
# 📌 Sample 599
# ✔ Predict: 0, True: 0
#
# 📌 Sample 600
# ❌ Predict: 0, True: 1
#
# 📌 Sample 601
# ❌ Predict: 0, True: 6
#
# 📌 Sample 602
# ❌ Predict: 0, True: 4
#
# 📌 Sample 603
# ❌ Predict: 0, True: 3
#
# 📌 Sample 604
# ❌ Predict: 0, True: 2
#
# 📌 Sample 605
# ❌ Predict: 0, True: 6
#
# 📌 Sample 606
# ❌ Predict: 0, True: 3
#
# 📌 Sample 607
# ❌ Predict: 0, True: 3
#
# 📌 Sample 608
# ❌ Predict: 0, True: 3
#
# 📌 Sample 609
# ❌ Predict: 0, True: 3
#
# 📌 Sample 610
# ✔ Predict: 0, True: 0
#
# 📌 Sample 611
# ❌ Predict: 0, True: 6
#
# 📌 Sample 612
# ❌ Predict: 0, True: 2
#
# 📌 Sample 613
# ❌ Predict: 0, True: 7
#
# 📌 Sample 614
# ❌ Predict: 0, True: 1
#
# 📌 Sample 615
# ❌ Predict: 0, True: 1
#
# 📌 Sample 616
# ❌ Predict: 0, True: 1
#
# 📌 Sample 617
# ❌ Predict: 0, True: 1
#
# 📌 Sample 618
# ❌ Predict: 0, True: 3
#
# 📌 Sample 619
# ❌ Predict: 1, True: 7
#
# 📌 Sample 620
# ❌ Predict: 1, True: 4
#
# 📌 Sample 621
# ❌ Predict: 1, True: 8
#
# 📌 Sample 622
# ❌ Predict: 1, True: 6
#
# 📌 Sample 623
# ❌ Predict: 1, True: 6
#
# 📌 Sample 624
# ❌ Predict: 1, True: 3
#
# 📌 Sample 625
# ❌ Predict: 1, True: 6
#
# 📌 Sample 626
# ❌ Predict: 1, True: 6
#
# 📌 Sample 627
# ❌ Predict: 1, True: 7
#
# 📌 Sample 628
# ❌ Predict: 1, True: 5
#
# 📌 Sample 629
# ❌ Predict: 1, True: 5
#
# 📌 Sample 630
# ❌ Predict: 1, True: 9
#
# 📌 Sample 631
# ❌ Predict: 1, True: 2
#
# 📌 Sample 632
# ❌ Predict: 1, True: 9
#
# 📌 Sample 633
# ❌ Predict: 1, True: 8
#
# 📌 Sample 634
# ❌ Predict: 1, True: 3
#
# 📌 Sample 635
# ✔ Predict: 1, True: 1
#
# 📌 Sample 636
# ❌ Predict: 1, True: 6
#
# 📌 Sample 637
# ❌ Predict: 1, True: 8
#
# 📌 Sample 638
# ❌ Predict: 1, True: 0
#
# 📌 Sample 639
# ✔ Predict: 3, True: 3
#
# 📌 Sample 640
# ❌ Predict: 6, True: 4
#
# 📌 Sample 641
# ❌ Predict: 1, True: 0
#
# 📌 Sample 642
# ❌ Predict: 3, True: 2
#
# 📌 Sample 643
# ❌ Predict: 6, True: 2
#
# 📌 Sample 644
# ❌ Predict: 6, True: 2
#
# 📌 Sample 645
# ✔ Predict: 6, True: 6
#
# 📌 Sample 646
# ❌ Predict: 1, True: 9
#
# 📌 Sample 647
# ❌ Predict: 1, True: 9
#
# 📌 Sample 648
# ❌ Predict: 1, True: 5
#
# 📌 Sample 649
# ❌ Predict: 3, True: 7
#
# 📌 Sample 650
# ✔ Predict: 3, True: 3
#
# 📌 Sample 651
# ❌ Predict: 1, True: 3
#
# 📌 Sample 652
# ❌ Predict: 6, True: 7
#
# 📌 Sample 653
# ❌ Predict: 1, True: 9
#
# 📌 Sample 654
# ❌ Predict: 1, True: 5
#
# 📌 Sample 655
# ❌ Predict: 3, True: 9
#
# 📌 Sample 656
# ❌ Predict: 3, True: 8
#
# 📌 Sample 657
# ❌ Predict: 6, True: 3
#
# 📌 Sample 658
# ❌ Predict: 3, True: 5
#
# 📌 Sample 659
# ❌ Predict: 3, True: 5
#
# 📌 Sample 660
# ✔ Predict: 3, True: 3
#
# 📌 Sample 661
# ❌ Predict: 3, True: 2
#
# 📌 Sample 662
# ❌ Predict: 3, True: 4
#
# 📌 Sample 663
# ✔ Predict: 3, True: 3
#
# 📌 Sample 664
# ✔ Predict: 3, True: 3
#
# 📌 Sample 665
# ❌ Predict: 3, True: 5
#
# 📌 Sample 666
# ❌ Predict: 3, True: 9
#
# 📌 Sample 667
# ❌ Predict: 3, True: 1
#
# 📌 Sample 668
# ❌ Predict: 3, True: 8
#
# 📌 Sample 669
# ❌ Predict: 3, True: 4
#
# 📌 Sample 670
# ❌ Predict: 3, True: 8
#
# 📌 Sample 671
# ❌ Predict: 3, True: 9
#
# 📌 Sample 672
# ❌ Predict: 3, True: 2
#
# 📌 Sample 673
# ❌ Predict: 3, True: 2
#
# 📌 Sample 674
# ❌ Predict: 3, True: 7
#
# 📌 Sample 675
# ❌ Predict: 3, True: 2
#
# 📌 Sample 676
# ❌ Predict: 3, True: 5
#
# 📌 Sample 677
# ❌ Predict: 3, True: 9
#
# 📌 Sample 678
# ❌ Predict: 3, True: 2
#
# 📌 Sample 679
# ❌ Predict: 3, True: 8
#
# 📌 Sample 680
# ❌ Predict: 3, True: 6
#
# 📌 Sample 681
# ✔ Predict: 3, True: 3
#
# 📌 Sample 682
# ❌ Predict: 3, True: 0
#
# 📌 Sample 683
# ✔ Predict: 3, True: 3
#
# 📌 Sample 684
# ✔ Predict: 3, True: 3
#
# 📌 Sample 685
# ❌ Predict: 3, True: 2
#
# 📌 Sample 686
# ❌ Predict: 3, True: 0
#
# 📌 Sample 687
# ❌ Predict: 3, True: 6
#
# 📌 Sample 688
# ❌ Predict: 3, True: 7
#
# 📌 Sample 689
# ❌ Predict: 3, True: 9
#
# 📌 Sample 690
# ❌ Predict: 3, True: 4
#
# 📌 Sample 691
# ❌ Predict: 3, True: 0
#
# 📌 Sample 692
# ❌ Predict: 3, True: 0
#
# 📌 Sample 693
# ❌ Predict: 3, True: 0
#
# 📌 Sample 694
# ❌ Predict: 3, True: 9
#
# 📌 Sample 695
# ❌ Predict: 3, True: 5
#
# 📌 Sample 696
# ❌ Predict: 3, True: 8
#
# 📌 Sample 697
# ❌ Predict: 3, True: 0
#
# 📌 Sample 698
# ❌ Predict: 3, True: 0
#
# 📌 Sample 699
# ❌ Predict: 3, True: 7
#
# 📌 Sample 700
# ❌ Predict: 3, True: 1
#
# 📌 Sample 701
# ❌ Predict: 3, True: 8
#
# 📌 Sample 702
# ❌ Predict: 3, True: 2
#
# 📌 Sample 703
# ❌ Predict: 3, True: 2
#
# 📌 Sample 704
# ❌ Predict: 0, True: 8
#
# 📌 Sample 705
# ✔ Predict: 3, True: 3
#
# 📌 Sample 706
# ❌ Predict: 0, True: 7
#
# 📌 Sample 707
# ❌ Predict: 0, True: 4
#
# 📌 Sample 708
# ❌ Predict: 0, True: 3
#
# 📌 Sample 709
# ❌ Predict: 3, True: 1
#
# 📌 Sample 710
# ❌ Predict: 0, True: 2
#
# 📌 Sample 711
# ❌ Predict: 0, True: 1
#
# 📌 Sample 712
# ❌ Predict: 0, True: 4
#
# 📌 Sample 713
# ❌ Predict: 0, True: 3
#
# 📌 Sample 714
# ❌ Predict: 0, True: 9
#
# 📌 Sample 715
# ❌ Predict: 3, True: 5
#
# 📌 Sample 716
# ❌ Predict: 0, True: 7
#
# 📌 Sample 717
# ❌ Predict: 0, True: 3
#
# 📌 Sample 718
# ❌ Predict: 3, True: 5
#
# 📌 Sample 719
# ✔ Predict: 0, True: 0
#
# 📌 Sample 720
# ❌ Predict: 3, True: 9
#
# 📌 Sample 721
# ✔ Predict: 3, True: 3
#
# 📌 Sample 722
# ✔ Predict: 3, True: 3
#
# 📌 Sample 723
# ❌ Predict: 3, True: 6
#
# 📌 Sample 724
# ❌ Predict: 3, True: 9
#
# 📌 Sample 725
# ❌ Predict: 0, True: 9
#
# 📌 Sample 726
# ❌ Predict: 3, True: 4
#
# 📌 Sample 727
# ❌ Predict: 3, True: 6
#
# 📌 Sample 728
# ❌ Predict: 3, True: 0
#
# 📌 Sample 729
# ❌ Predict: 3, True: 6
#
# 📌 Sample 730
# ✔ Predict: 3, True: 3
#
# 📌 Sample 731
# ❌ Predict: 3, True: 5
#
# 📌 Sample 732
# ❌ Predict: 3, True: 0
#
# 📌 Sample 733
# ❌ Predict: 3, True: 1
#
# 📌 Sample 734
# ❌ Predict: 3, True: 0
#
# 📌 Sample 735
# ❌ Predict: 3, True: 1
#
# 📌 Sample 736
# ❌ Predict: 3, True: 8
#
# 📌 Sample 737
# ❌ Predict: 3, True: 8
#
# 📌 Sample 738
# ✔ Predict: 3, True: 3
#
# 📌 Sample 739
# ❌ Predict: 3, True: 1
#
# 📌 Sample 740
# ❌ Predict: 3, True: 2
#
# 📌 Sample 741
# ❌ Predict: 3, True: 0
#
# 📌 Sample 742
# ❌ Predict: 3, True: 5
#
# 📌 Sample 743
# ❌ Predict: 3, True: 5
#
# 📌 Sample 744
# ❌ Predict: 0, True: 1
#
# 📌 Sample 745
# ❌ Predict: 0, True: 3
#
# 📌 Sample 746
# ❌ Predict: 0, True: 1
#
# 📌 Sample 747
# ✔ Predict: 0, True: 0
#
# 📌 Sample 748
# ❌ Predict: 3, True: 6
#
# 📌 Sample 749
# ❌ Predict: 0, True: 6
#
# 📌 Sample 750
# ❌ Predict: 0, True: 5
#
# 📌 Sample 751
# ❌ Predict: 0, True: 9
#
# 📌 Sample 752
# ❌ Predict: 0, True: 4
#
# 📌 Sample 753
# ❌ Predict: 3, True: 5
#
# 📌 Sample 754
# ❌ Predict: 0, True: 1
#
# 📌 Sample 755
# ❌ Predict: 0, True: 8
#
# 📌 Sample 756
# ❌ Predict: 0, True: 9
#
# 📌 Sample 757
# ❌ Predict: 0, True: 5
#
# 📌 Sample 758
# ❌ Predict: 0, True: 1
#
# 📌 Sample 759
# ❌ Predict: 3, True: 5
#
# 📌 Sample 760
# ❌ Predict: 3, True: 4
#
# 📌 Sample 761
# ✔ Predict: 3, True: 3
#
# 📌 Sample 762
# ❌ Predict: 3, True: 6
#
# 📌 Sample 763
# ❌ Predict: 3, True: 1
#
# 📌 Sample 764
# ❌ Predict: 3, True: 1
#
# 📌 Sample 765
# ❌ Predict: 3, True: 6
#
# 📌 Sample 766
# ❌ Predict: 3, True: 6
#
# 📌 Sample 767
# ❌ Predict: 1, True: 2
#
# 📌 Sample 768
# ❌ Predict: 1, True: 8
#
# 📌 Sample 769
# ❌ Predict: 3, True: 2
#
# 📌 Sample 770
# ❌ Predict: 1, True: 0
#
# 📌 Sample 771
# ❌ Predict: 3, True: 8
#
# 📌 Sample 772
# ❌ Predict: 1, True: 3
#
# 📌 Sample 773
# ❌ Predict: 3, True: 5
#
# 📌 Sample 774
# ❌ Predict: 1, True: 9
#
# 📌 Sample 775
# ❌ Predict: 3, True: 6
#
# 📌 Sample 776
# ✔ Predict: 3, True: 3
#
# 📌 Sample 777
# ❌ Predict: 3, True: 4
#
# 📌 Sample 778
# ✔ Predict: 3, True: 3
#
# 📌 Sample 779
# ❌ Predict: 3, True: 4
#
# 📌 Sample 780
# ❌ Predict: 3, True: 5
#
# 📌 Sample 781
# ❌ Predict: 3, True: 8
#
# 📌 Sample 782
# ✔ Predict: 3, True: 3
#
# 📌 Sample 783
# ❌ Predict: 3, True: 9
#
# 📌 Sample 784
# ❌ Predict: 3, True: 6
#
# 📌 Sample 785
# ❌ Predict: 3, True: 5
#
# 📌 Sample 786
# ❌ Predict: 3, True: 0
#
# 📌 Sample 787
# ❌ Predict: 3, True: 2
#
# 📌 Sample 788
# ❌ Predict: 3, True: 2
#
# 📌 Sample 789
# ❌ Predict: 3, True: 4
#
# 📌 Sample 790
# ✔ Predict: 1, True: 1
#
# 📌 Sample 791
# ❌ Predict: 3, True: 8
#
# 📌 Sample 792
# ❌ Predict: 3, True: 9
#
# 📌 Sample 793
# ❌ Predict: 1, True: 2
#
# 📌 Sample 794
# ❌ Predict: 3, True: 1
#
# 📌 Sample 795
# ❌ Predict: 3, True: 6
#
# 📌 Sample 796
# ❌ Predict: 3, True: 9
#
# 📌 Sample 797
# ❌ Predict: 1, True: 4
#
# 📌 Sample 798
# ❌ Predict: 1, True: 6
#
# 📌 Sample 799
# ❌ Predict: 1, True: 7
#
# 📌 Sample 800
# ✔ Predict: 1, True: 1
#
# 📌 Sample 801
# ✔ Predict: 1, True: 1
#
# 📌 Sample 802
# ❌ Predict: 1, True: 5
#
# 📌 Sample 803
# ✔ Predict: 1, True: 1
#
# 📌 Sample 804
# ✔ Predict: 3, True: 3
#
# 📌 Sample 805
# ❌ Predict: 3, True: 2
#
# 📌 Sample 806
# ✔ Predict: 1, True: 1
#
# 📌 Sample 807
# ❌ Predict: 1, True: 4
#
# 📌 Sample 808
# ❌ Predict: 1, True: 5
#
# 📌 Sample 809
# ❌ Predict: 1, True: 3
#
# 📌 Sample 810
# ❌ Predict: 1, True: 5
#
# 📌 Sample 811
# ❌ Predict: 1, True: 2
#
# 📌 Sample 812
# ❌ Predict: 3, True: 4
#
# 📌 Sample 813
# ✔ Predict: 1, True: 1
#
# 📌 Sample 814
# ❌ Predict: 1, True: 0
#
# 📌 Sample 815
# ❌ Predict: 1, True: 8
#
# 📌 Sample 816
# ❌ Predict: 1, True: 6
#
# 📌 Sample 817
# ❌ Predict: 1, True: 8
#
# 📌 Sample 818
# ❌ Predict: 1, True: 3
#
# 📌 Sample 819
# ❌ Predict: 3, True: 6
#
# 📌 Sample 820
# ❌ Predict: 3, True: 4
#
# 📌 Sample 821
# ❌ Predict: 1, True: 8
#
# 📌 Sample 822
# ❌ Predict: 3, True: 7
#
# 📌 Sample 823
# ❌ Predict: 1, True: 7
#
# 📌 Sample 824
# ✔ Predict: 3, True: 3
#
# 📌 Sample 825
# ❌ Predict: 1, True: 9
#
# 📌 Sample 826
# ❌ Predict: 3, True: 0
#
# 📌 Sample 827
# ✔ Predict: 3, True: 3
#
# 📌 Sample 828
# ✔ Predict: 3, True: 3
#
# 📌 Sample 829
# ✔ Predict: 3, True: 3
#
# 📌 Sample 830
# ❌ Predict: 3, True: 9
#
# 📌 Sample 831
# ❌ Predict: 3, True: 0
#
# 📌 Sample 832
# ❌ Predict: 3, True: 5
#
# 📌 Sample 833
# ❌ Predict: 3, True: 4
#
# 📌 Sample 834
# ✔ Predict: 3, True: 3
#
# 📌 Sample 835
# ❌ Predict: 3, True: 7
#
# 📌 Sample 836
# ❌ Predict: 3, True: 5
#
# 📌 Sample 837
# ❌ Predict: 3, True: 5
#
# 📌 Sample 838
# ❌ Predict: 3, True: 9
#
# 📌 Sample 839
# ✔ Predict: 1, True: 1
#
# 📌 Sample 840
# ❌ Predict: 3, True: 9
#
# 📌 Sample 841
# ❌ Predict: 3, True: 0
#
# 📌 Sample 842
# ❌ Predict: 1, True: 8
#
# 📌 Sample 843
# ✔ Predict: 3, True: 3
#
# 📌 Sample 844
# ❌ Predict: 1, True: 5
#
# 📌 Sample 845
# ❌ Predict: 1, True: 9
#
# 📌 Sample 846
# ❌ Predict: 3, True: 5
#
# 📌 Sample 847
# ❌ Predict: 1, True: 9
#
# 📌 Sample 848
# ❌ Predict: 1, True: 7
#
# 📌 Sample 849
# ❌ Predict: 1, True: 7
#
# 📌 Sample 850
# ❌ Predict: 3, True: 6
#
# 📌 Sample 851
# ❌ Predict: 3, True: 2
#
# 📌 Sample 852
# ❌ Predict: 1, True: 6
#
# 📌 Sample 853
# ❌ Predict: 3, True: 1
#
# 📌 Sample 854
# ❌ Predict: 1, True: 8
#
# 📌 Sample 855
# ✔ Predict: 3, True: 3
#
# 📌 Sample 856
# ✔ Predict: 3, True: 3
#
# 📌 Sample 857
# ❌ Predict: 1, True: 9
#
# 📌 Sample 858
# ❌ Predict: 1, True: 0
#
# 📌 Sample 859
# ❌ Predict: 1, True: 7
#
# 📌 Sample 860
# ✔ Predict: 3, True: 3
#
# 📌 Sample 861
# ❌ Predict: 1, True: 9
#
# 📌 Sample 862
# ❌ Predict: 3, True: 2
#
# 📌 Sample 863
# ✔ Predict: 9, True: 9
#
# 📌 Sample 864
# ❌ Predict: 1, True: 3
#
# 📌 Sample 865
# ❌ Predict: 3, True: 8
#
# 📌 Sample 866
# ❌ Predict: 9, True: 7
#
# 📌 Sample 867
# ❌ Predict: 3, True: 1
#
# 📌 Sample 868
# ❌ Predict: 9, True: 2
#
# 📌 Sample 869
# ❌ Predict: 9, True: 7
#
# 📌 Sample 870
# ❌ Predict: 9, True: 7
#
# 📌 Sample 871
# ❌ Predict: 3, True: 6
#
# 📌 Sample 872
# ❌ Predict: 3, True: 2
#
# 📌 Sample 873
# ❌ Predict: 3, True: 6
#
# 📌 Sample 874
# ❌ Predict: 3, True: 9
#
# 📌 Sample 875
# ✔ Predict: 3, True: 3
#
# 📌 Sample 876
# ❌ Predict: 3, True: 7
#
# 📌 Sample 877
# ❌ Predict: 3, True: 2
#
# 📌 Sample 878
# ❌ Predict: 3, True: 9
#
# 📌 Sample 879
# ❌ Predict: 3, True: 1
#
# 📌 Sample 880
# ❌ Predict: 3, True: 1
#
# 📌 Sample 881
# ❌ Predict: 9, True: 7
#
# 📌 Sample 882
# ❌ Predict: 9, True: 8
#
# 📌 Sample 883
# ❌ Predict: 9, True: 0
#
# 📌 Sample 884
# ❌ Predict: 9, True: 5
#
# 📌 Sample 885
# ❌ Predict: 9, True: 6
#
# 📌 Sample 886
# ✔ Predict: 9, True: 9
#
# 📌 Sample 887
# ❌ Predict: 3, True: 4
#
# 📌 Sample 888
# ❌ Predict: 9, True: 7
#
# 📌 Sample 889
# ❌ Predict: 3, True: 5
#
# 📌 Sample 890
# ❌ Predict: 9, True: 5
#
# 📌 Sample 891
# ❌ Predict: 9, True: 2
#
# 📌 Sample 892
# ❌ Predict: 9, True: 7
#
# 📌 Sample 893
# ❌ Predict: 9, True: 1
#
# 📌 Sample 894
# ❌ Predict: 9, True: 3
#
# 📌 Sample 895
# ❌ Predict: 9, True: 1
#
# 📌 Sample 896
# ❌ Predict: 9, True: 0
#
# 📌 Sample 897
# ❌ Predict: 9, True: 3
#
# 📌 Sample 898
# ❌ Predict: 7, True: 1
#
# 📌 Sample 899
# ❌ Predict: 7, True: 4
#
# 📌 Sample 900
# ❌ Predict: 7, True: 1
#
# 📌 Sample 901
# ❌ Predict: 9, True: 1
#
# 📌 Sample 902
# ❌ Predict: 3, True: 6
#
# 📌 Sample 903
# ✔ Predict: 9, True: 9
#
# 📌 Sample 904
# ❌ Predict: 7, True: 5
#
# 📌 Sample 905
# ❌ Predict: 9, True: 1
#
# 📌 Sample 906
# ❌ Predict: 3, True: 8
#
# 📌 Sample 907
# ❌ Predict: 3, True: 4
#
# 📌 Sample 908
# ❌ Predict: 1, True: 5
#
# 📌 Sample 909
# ❌ Predict: 1, True: 0
#
# 📌 Sample 910
# ❌ Predict: 3, True: 4
#
# 📌 Sample 911
# ❌ Predict: 1, True: 6
#
# 📌 Sample 912
# ✔ Predict: 1, True: 1
#
# 📌 Sample 913
# ❌ Predict: 3, True: 5
#
# 📌 Sample 914
# ❌ Predict: 1, True: 9
#
# 📌 Sample 915
# ❌ Predict: 3, True: 4
#
# 📌 Sample 916
# ❌ Predict: 1, True: 8
#
# 📌 Sample 917
# ❌ Predict: 1, True: 0
#
# 📌 Sample 918
# ❌ Predict: 1, True: 3
#
# 📌 Sample 919
# ❌ Predict: 1, True: 5
#
# 📌 Sample 920
# ❌ Predict: 1, True: 8
#
# 📌 Sample 921
# ✔ Predict: 1, True: 1
#
# 📌 Sample 922
# ❌ Predict: 1, True: 4
#
# 📌 Sample 923
# ❌ Predict: 1, True: 7
#
# 📌 Sample 924
# ✔ Predict: 3, True: 3
#
# 📌 Sample 925
# ❌ Predict: 1, True: 7
#
# 📌 Sample 926
# ❌ Predict: 3, True: 6
#
# 📌 Sample 927
# ❌ Predict: 1, True: 8
#
# 📌 Sample 928
# ❌ Predict: 1, True: 7
#
# 📌 Sample 929
# ❌ Predict: 3, True: 4
#
# 📌 Sample 930
# ❌ Predict: 3, True: 2
#
# 📌 Sample 931
# ❌ Predict: 3, True: 2
#
# 📌 Sample 932
# ✔ Predict: 1, True: 1
#
# 📌 Sample 933
# ✔ Predict: 3, True: 3
#
# 📌 Sample 934
# ❌ Predict: 3, True: 2
#
# 📌 Sample 935
# ❌ Predict: 3, True: 6
#
# 📌 Sample 936
# ✔ Predict: 1, True: 1
#
# 📌 Sample 937
# ❌ Predict: 1, True: 0
#
# 📌 Sample 938
# ❌ Predict: 1, True: 5
#
# 📌 Sample 939
# ❌ Predict: 1, True: 9
#
# 📌 Sample 940
# ✔ Predict: 1, True: 1
#
# 📌 Sample 941
# ❌ Predict: 3, True: 5
#
# 📌 Sample 942
# ❌ Predict: 1, True: 4
#
# 📌 Sample 943
# ❌ Predict: 1, True: 9
#
# 📌 Sample 944
# ❌ Predict: 1, True: 2
#
# 📌 Sample 945
# ❌ Predict: 3, True: 6
#
# 📌 Sample 946
# ✔ Predict: 1, True: 1
#
# 📌 Sample 947
# ❌ Predict: 1, True: 2
#
# 📌 Sample 948
# ❌ Predict: 1, True: 0
#
# 📌 Sample 949
# ✔ Predict: 1, True: 1
#
# 📌 Sample 950
# ❌ Predict: 1, True: 9
#
# 📌 Sample 951
# ❌ Predict: 1, True: 2
#
# 📌 Sample 952
# ✔ Predict: 1, True: 1
#
# 📌 Sample 953
# ❌ Predict: 1, True: 5
#
# 📌 Sample 954
# ❌ Predict: 3, True: 5
#
# 📌 Sample 955
# ❌ Predict: 1, True: 5
#
# 📌 Sample 956
# ❌ Predict: 1, True: 5
#
# 📌 Sample 957
# ❌ Predict: 1, True: 7
#
# 📌 Sample 958
# ❌ Predict: 1, True: 8
#
# 📌 Sample 959
# ❌ Predict: 1, True: 0
#
# 📌 Sample 960
# ❌ Predict: 1, True: 8
#
# 📌 Sample 961
# ✔ Predict: 3, True: 3
#
# 📌 Sample 962
# ❌ Predict: 5, True: 2
#
# 📌 Sample 963
# ❌ Predict: 5, True: 7
#
# 📌 Sample 964
# ❌ Predict: 1, True: 8
#
# 📌 Sample 965
# ❌ Predict: 5, True: 9
#
# 📌 Sample 966
# ❌ Predict: 5, True: 1
#
# 📌 Sample 967
# ❌ Predict: 5, True: 6
#
# 📌 Sample 968
# ❌ Predict: 5, True: 0
#
# 📌 Sample 969
# ❌ Predict: 3, True: 4
#
# 📌 Sample 970
# ✔ Predict: 3, True: 3
#
# 📌 Sample 971
# ❌ Predict: 5, True: 9
#
# 📌 Sample 972
# ❌ Predict: 5, True: 4
#
# 📌 Sample 973
# ❌ Predict: 3, True: 6
#
# 📌 Sample 974
# ❌ Predict: 3, True: 6
#
# 📌 Sample 975
# ❌ Predict: 3, True: 5
#
# 📌 Sample 976
# ❌ Predict: 5, True: 0
#
# 📌 Sample 977
# ✔ Predict: 3, True: 3
#
# 📌 Sample 978
# ❌ Predict: 5, True: 1
#
# 📌 Sample 979
# ❌ Predict: 5, True: 0
#
# 📌 Sample 980
# ❌ Predict: 5, True: 9
#
# 📌 Sample 981
# ❌ Predict: 5, True: 9
#
# 📌 Sample 982
# ❌ Predict: 5, True: 8
#
# 📌 Sample 983
# ❌ Predict: 5, True: 9
#
# 📌 Sample 984
# ❌ Predict: 5, True: 3
#
# 📌 Sample 985
# ✔ Predict: 0, True: 0
#
# 📌 Sample 986
# ❌ Predict: 0, True: 9
#
# 📌 Sample 987
# ❌ Predict: 0, True: 1
#
# 📌 Sample 988
# ❌ Predict: 0, True: 8
#
# 📌 Sample 989
# ❌ Predict: 0, True: 8
#
# 📌 Sample 990
# ❌ Predict: 0, True: 8
#
# 📌 Sample 991
# ❌ Predict: 0, True: 7
#
# 📌 Sample 992
# ❌ Predict: 0, True: 3
#
# 📌 Sample 993
# ❌ Predict: 8, True: 5
#
# 📌 Sample 994
# ❌ Predict: 8, True: 1
#
# 📌 Sample 995
# ❌ Predict: 9, True: 7
#
# 📌 Sample 996
# ✔ Predict: 8, True: 8
#
# 📌 Sample 997
# ❌ Predict: 8, True: 7
#
# 📌 Sample 998
# ❌ Predict: 8, True: 0
#
# 📌 Sample 999
# ❌ Predict: 5, True: 9
#
# 📌 Sample 1000
# ❌ Predict: 8, True: 2
#
# 📌 Sample 1001
# ❌ Predict: 9, True: 1
#
# 📌 Sample 1002
# ❌ Predict: 1, True: 4
#
# 📌 Sample 1003
# ❌ Predict: 8, True: 9
#
# 📌 Sample 1004
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1005
# ❌ Predict: 1, True: 4
#
# 📌 Sample 1006
# ❌ Predict: 8, True: 0
#
# 📌 Sample 1007
# ❌ Predict: 1, True: 3
#
# 📌 Sample 1008
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1009
# ❌ Predict: 9, True: 6
#
# 📌 Sample 1010
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1011
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1012
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1013
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1014
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1015
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1016
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1017
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1018
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1019
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1020
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1021
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1022
# ❌ Predict: 3, True: 8
#
# 📌 Sample 1023
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1024
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1025
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1026
# ❌ Predict: 3, True: 8
#
# 📌 Sample 1027
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1028
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1029
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1030
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1031
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1032
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1033
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1034
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1035
# ❌ Predict: 3, True: 9
#
# 📌 Sample 1036
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1037
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1038
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1039
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1040
# ❌ Predict: 3, True: 9
#
# 📌 Sample 1041
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1042
# ❌ Predict: 3, True: 8
#
# 📌 Sample 1043
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1044
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1045
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1046
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1047
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1048
# ❌ Predict: 1, True: 9
#
# 📌 Sample 1049
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1050
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1051
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1052
# ✔ Predict: 8, True: 8
#
# 📌 Sample 1053
# ❌ Predict: 8, True: 9
#
# 📌 Sample 1054
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1055
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1056
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1057
# ✔ Predict: 8, True: 8
#
# 📌 Sample 1058
# ✔ Predict: 8, True: 8
#
# 📌 Sample 1059
# ❌ Predict: 8, True: 9
#
# 📌 Sample 1060
# ❌ Predict: 8, True: 0
#
# 📌 Sample 1061
# ❌ Predict: 8, True: 2
#
# 📌 Sample 1062
# ❌ Predict: 8, True: 1
#
# 📌 Sample 1063
# ❌ Predict: 8, True: 7
#
# 📌 Sample 1064
# ❌ Predict: 8, True: 5
#
# 📌 Sample 1065
# ❌ Predict: 8, True: 0
#
# 📌 Sample 1066
# ❌ Predict: 8, True: 3
#
# 📌 Sample 1067
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1068
# ❌ Predict: 3, True: 9
#
# 📌 Sample 1069
# ❌ Predict: 8, True: 0
#
# 📌 Sample 1070
# ❌ Predict: 8, True: 9
#
# 📌 Sample 1071
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1072
# ❌ Predict: 0, True: 1
#
# 📌 Sample 1073
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1074
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1075
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1076
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1077
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1078
# ❌ Predict: 0, True: 4
#
# 📌 Sample 1079
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1080
# ❌ Predict: 0, True: 6
#
# 📌 Sample 1081
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1082
# ❌ Predict: 0, True: 4
#
# 📌 Sample 1083
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1084
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1085
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1086
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1087
# ❌ Predict: 0, True: 3
#
# 📌 Sample 1088
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1089
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1090
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1091
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1092
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1093
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1094
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1095
# ❌ Predict: 0, True: 7
#
# 📌 Sample 1096
# ❌ Predict: 0, True: 1
#
# 📌 Sample 1097
# ❌ Predict: 0, True: 6
#
# 📌 Sample 1098
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1099
# ❌ Predict: 0, True: 3
#
# 📌 Sample 1100
# ❌ Predict: 9, True: 7
#
# 📌 Sample 1101
# ❌ Predict: 0, True: 1
#
# 📌 Sample 1102
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1103
# ✔ Predict: 9, True: 9
#
# 📌 Sample 1104
# ❌ Predict: 9, True: 6
#
# 📌 Sample 1105
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1106
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1107
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1108
# ❌ Predict: 0, True: 1
#
# 📌 Sample 1109
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1110
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1111
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1112
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1113
# ❌ Predict: 3, True: 9
#
# 📌 Sample 1114
# ✔ Predict: 9, True: 9
#
# 📌 Sample 1115
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1116
# ❌ Predict: 0, True: 1
#
# 📌 Sample 1117
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1118
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1119
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1120
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1121
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1122
# ❌ Predict: 0, True: 3
#
# 📌 Sample 1123
# ❌ Predict: 0, True: 2
#
# 📌 Sample 1124
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1125
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1126
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1127
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1128
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1129
# ✔ Predict: 9, True: 9
#
# 📌 Sample 1130
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1131
# ❌ Predict: 0, True: 6
#
# 📌 Sample 1132
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1133
# ❌ Predict: 5, True: 7
#
# 📌 Sample 1134
# ❌ Predict: 5, True: 8
#
# 📌 Sample 1135
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1136
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1137
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1138
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1139
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1140
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1141
# ❌ Predict: 5, True: 9
#
# 📌 Sample 1142
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1143
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1144
# ❌ Predict: 9, True: 8
#
# 📌 Sample 1145
# ❌ Predict: 5, True: 0
#
# 📌 Sample 1146
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1147
# ❌ Predict: 3, True: 8
#
# 📌 Sample 1148
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1149
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1150
# ❌ Predict: 3, True: 0
#
# 📌 Sample 1151
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1152
# ❌ Predict: 9, True: 0
#
# 📌 Sample 1153
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1154
# ❌ Predict: 8, True: 1
#
# 📌 Sample 1155
# ❌ Predict: 9, True: 3
#
# 📌 Sample 1156
# ❌ Predict: 9, True: 7
#
# 📌 Sample 1157
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1158
# ❌ Predict: 0, True: 7
#
# 📌 Sample 1159
# ❌ Predict: 8, True: 5
#
# 📌 Sample 1160
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1161
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1162
# ❌ Predict: 9, True: 6
#
# 📌 Sample 1163
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1164
# ❌ Predict: 8, True: 0
#
# 📌 Sample 1165
# ❌ Predict: 3, True: 9
#
# 📌 Sample 1166
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1167
# ❌ Predict: 9, True: 8
#
# 📌 Sample 1168
# ✔ Predict: 9, True: 9
#
# 📌 Sample 1169
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1170
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1171
# ❌ Predict: 9, True: 2
#
# 📌 Sample 1172
# ❌ Predict: 9, True: 0
#
# 📌 Sample 1173
# ❌ Predict: 9, True: 0
#
# 📌 Sample 1174
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1175
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1176
# ❌ Predict: 0, True: 3
#
# 📌 Sample 1177
# ❌ Predict: 3, True: 8
#
# 📌 Sample 1178
# ❌ Predict: 3, True: 9
#
# 📌 Sample 1179
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1180
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1181
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1182
# ❌ Predict: 0, True: 7
#
# 📌 Sample 1183
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1184
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1185
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1186
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1187
# ❌ Predict: 0, True: 5
#
# 📌 Sample 1188
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1189
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1190
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1191
# ❌ Predict: 0, True: 2
#
# 📌 Sample 1192
# ❌ Predict: 0, True: 2
#
# 📌 Sample 1193
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1194
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1195
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1196
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1197
# ❌ Predict: 3, True: 8
#
# 📌 Sample 1198
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1199
# ❌ Predict: 3, True: 6
#
# 📌 Sample 1200
# ❌ Predict: 3, True: 1
#
# 📌 Sample 1201
# ❌ Predict: 3, True: 5
#
# 📌 Sample 1202
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1203
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1204
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1205
# ❌ Predict: 3, True: 4
#
# 📌 Sample 1206
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1207
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1208
# ❌ Predict: 6, True: 7
#
# 📌 Sample 1209
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1210
# ❌ Predict: 6, True: 2
#
# 📌 Sample 1211
# ❌ Predict: 6, True: 7
#
# 📌 Sample 1212
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1213
# ❌ Predict: 3, True: 7
#
# 📌 Sample 1214
# ✔ Predict: 3, True: 3
#
# 📌 Sample 1215
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1216
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1217
# ❌ Predict: 0, True: 8
#
# 📌 Sample 1218
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1219
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1220
# ❌ Predict: 0, True: 9
#
# 📌 Sample 1221
# ❌ Predict: 3, True: 2
#
# 📌 Sample 1222
# ❌ Predict: 9, True: 4
#
# 📌 Sample 1223
# ❌ Predict: 9, True: 1
#
# 📌 Sample 1224
# ✔ Predict: 0, True: 0
#
# 📌 Sample 1225
# ❌ Predict: 6, True: 4
#
# 📌 Sample 1226
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1227
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1228
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1229
# ❌ Predict: 6, True: 4
#
# 📌 Sample 1230
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1231
# ❌ Predict: 6, True: 1
#
# 📌 Sample 1232
# ❌ Predict: 6, True: 1
#
# 📌 Sample 1233
# ❌ Predict: 6, True: 8
#
# 📌 Sample 1234
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1235
# ❌ Predict: 6, True: 9
#
# 📌 Sample 1236
# ❌ Predict: 6, True: 0
#
# 📌 Sample 1237
# ❌ Predict: 6, True: 2
#
# 📌 Sample 1238
# ❌ Predict: 6, True: 4
#
# 📌 Sample 1239
# ❌ Predict: 6, True: 2
#
# 📌 Sample 1240
# ❌ Predict: 6, True: 0
#
# 📌 Sample 1241
# ❌ Predict: 6, True: 9
#
# 📌 Sample 1242
# ❌ Predict: 6, True: 1
#
# 📌 Sample 1243
# ❌ Predict: 6, True: 5
#
# 📌 Sample 1244
# ❌ Predict: 6, True: 0
#
# 📌 Sample 1245
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1246
# ❌ Predict: 6, True: 2
#
# 📌 Sample 1247
# ❌ Predict: 6, True: 9
#
# 📌 Sample 1248
# ❌ Predict: 6, True: 2
#
# 📌 Sample 1249
# ❌ Predict: 6, True: 1
#
# 📌 Sample 1250
# ❌ Predict: 6, True: 2
#
# 📌 Sample 1251
# ❌ Predict: 6, True: 1
#
# 📌 Sample 1252
# ❌ Predict: 6, True: 3
#
# 📌 Sample 1253
# ❌ Predict: 6, True: 5
#
# 📌 Sample 1254
# ❌ Predict: 6, True: 8
#
# 📌 Sample 1255
# ❌ Predict: 9, True: 1
#
# 📌 Sample 1256
# ✔ Predict: 6, True: 6
#
# 📌 Sample 1257
# ❌ Predict: 6, True: 0
#
# 📌 Sample 1258
# ❌ Predict: 6, True: 1
#
# 📌 Sample 1259
# ❌ Predict: 6, True: 5
#
# 📌 Sample 1260
# ❌ Predict: 6, True: 4
#
# 📌 Sample 1261
# ❌ Predict: 6, True: 3
#
# 📌 Sample 1262
# ❌ Predict: 9, True: 8
#
# 📌 Sample 1263
# ❌ Predict: 6, True: 3
#
# 📌 Sample 1264
# ❌ Predict: 6, True: 1
#
# 📌 Sample 1265
# ❌ Predict: 6, True: 5
#
# 📌 Sample 1266
# ❌ Predict: 1, True: 7
#
# 📌 Sample 1267
# ✔ Predict: 1, True: 1
#
# 📌 Sample 1268
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1269
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1270
# ❌ Predict: 1, True: 7
#
# 📌 Sample 1271
# ❌ Predict: 1, True: 6
#
# 📌 Sample 1272
# ❌ Predict: 1, True: 9
#
# 📌 Sample 1273
# ✔ Predict: 1, True: 1
#
# 📌 Sample 1274
# ❌ Predict: 1, True: 6
#
# 📌 Sample 1275
# ❌ Predict: 1, True: 2
#
# 📌 Sample 1276
# ✔ Predict: 1, True: 1
#
# 📌 Sample 1277
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1278
# ❌ Predict: 1, True: 3
#
# 📌 Sample 1279
# ❌ Predict: 1, True: 4
#
# 📌 Sample 1280
# ❌ Predict: 1, True: 3
#
# 📌 Sample 1281
# ❌ Predict: 1, True: 6
#
# 📌 Sample 1282
# ✔ Predict: 1, True: 1
#
# 📌 Sample 1283
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1284
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1285
# ❌ Predict: 1, True: 3
#
# 📌 Sample 1286
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1287
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1288
# ❌ Predict: 1, True: 7
#
# 📌 Sample 1289
# ❌ Predict: 1, True: 7
#
# 📌 Sample 1290
# ❌ Predict: 1, True: 2
#
# 📌 Sample 1291
# ❌ Predict: 1, True: 9
#
# 📌 Sample 1292
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1293
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1294
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1295
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1296
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1297
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1298
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1299
# ❌ Predict: 1, True: 3
#
# 📌 Sample 1300
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1301
# ❌ Predict: 1, True: 3
#
# 📌 Sample 1302
# ❌ Predict: 1, True: 6
#
# 📌 Sample 1303
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1304
# ❌ Predict: 1, True: 9
#
# 📌 Sample 1305
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1306
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1307
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1308
# ✔ Predict: 1, True: 1
#
# 📌 Sample 1309
# ❌ Predict: 1, True: 4
#
# 📌 Sample 1310
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1311
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1312
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1313
# ❌ Predict: 1, True: 7
#
# 📌 Sample 1314
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1315
# ❌ Predict: 1, True: 6
#
# 📌 Sample 1316
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1317
# ❌ Predict: 5, True: 9
#
# 📌 Sample 1318
# ❌ Predict: 1, True: 5
#
# 📌 Sample 1319
# ❌ Predict: 1, True: 0
#
# 📌 Sample 1320
# ❌ Predict: 5, True: 4
#
# 📌 Sample 1321
# ❌ Predict: 1, True: 8
#
# 📌 Sample 1322
# ❌ Predict: 5, True: 4
#
# 📌 Sample 1323
# ❌ Predict: 5, True: 2
#
# 📌 Sample 1324
# ❌ Predict: 5, True: 2
#
# 📌 Sample 1325
# ❌ Predict: 5, True: 3
#
# 📌 Sample 1326
# ❌ Predict: 5, True: 6
#
# ...
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49568
# ❌ Predict: 5, True: 3
#
# 📌 Sample 49569
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49570
# ❌ Predict: 7, True: 2
#
# 📌 Sample 49571
# ❌ Predict: 0, True: 8
#
# 📌 Sample 49572
# ❌ Predict: 3, True: 7
#
# 📌 Sample 49573
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49574
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49575
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49576
# ❌ Predict: 7, True: 3
#
# 📌 Sample 49577
# ❌ Predict: 2, True: 3
#
# 📌 Sample 49578
# ❌ Predict: 8, True: 9
#
# 📌 Sample 49579
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49580
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49581
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49582
# ❌ Predict: 8, True: 2
#
# 📌 Sample 49583
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49584
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49585
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49586
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49587
# ❌ Predict: 8, True: 3
#
# 📌 Sample 49588
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49589
# ❌ Predict: 3, True: 6
#
# 📌 Sample 49590
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49591
# ❌ Predict: 5, True: 3
#
# 📌 Sample 49592
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49593
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49594
# ❌ Predict: 8, True: 0
#
# 📌 Sample 49595
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49596
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49597
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49598
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49599
# ❌ Predict: 8, True: 0
#
# 📌 Sample 49600
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49601
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49602
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49603
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49604
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49605
# ❌ Predict: 3, True: 9
#
# 📌 Sample 49606
# ❌ Predict: 3, True: 1
#
# 📌 Sample 49607
# ❌ Predict: 5, True: 3
#
# 📌 Sample 49608
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49609
# ❌ Predict: 6, True: 2
#
# 📌 Sample 49610
# ❌ Predict: 4, True: 7
#
# 📌 Sample 49611
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49612
# ❌ Predict: 2, True: 3
#
# 📌 Sample 49613
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49614
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49615
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49616
# ❌ Predict: 0, True: 4
#
# 📌 Sample 49617
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49618
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49619
# ❌ Predict: 3, True: 4
#
# 📌 Sample 49620
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49621
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49622
# ❌ Predict: 0, True: 8
#
# 📌 Sample 49623
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49624
# ❌ Predict: 6, True: 3
#
# 📌 Sample 49625
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49626
# ❌ Predict: 5, True: 2
#
# 📌 Sample 49627
# ❌ Predict: 3, True: 6
#
# 📌 Sample 49628
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49629
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49630
# ❌ Predict: 3, True: 7
#
# 📌 Sample 49631
# ❌ Predict: 2, True: 7
#
# 📌 Sample 49632
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49633
# ❌ Predict: 6, True: 5
#
# 📌 Sample 49634
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49635
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49636
# ❌ Predict: 6, True: 2
#
# 📌 Sample 49637
# ❌ Predict: 1, True: 8
#
# 📌 Sample 49638
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49639
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49640
# ❌ Predict: 8, True: 2
#
# 📌 Sample 49641
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49642
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49643
# ❌ Predict: 3, True: 9
#
# 📌 Sample 49644
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49645
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49646
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49647
# ❌ Predict: 0, True: 1
#
# 📌 Sample 49648
# ❌ Predict: 6, True: 1
#
# 📌 Sample 49649
# ❌ Predict: 3, True: 6
#
# 📌 Sample 49650
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49651
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49652
# ❌ Predict: 8, True: 2
#
# 📌 Sample 49653
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49654
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49655
# ❌ Predict: 4, True: 2
#
# 📌 Sample 49656
# ❌ Predict: 7, True: 0
#
# 📌 Sample 49657
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49658
# ❌ Predict: 0, True: 8
#
# 📌 Sample 49659
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49660
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49661
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49662
# ❌ Predict: 4, True: 8
#
# 📌 Sample 49663
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49664
# ❌ Predict: 4, True: 3
#
# 📌 Sample 49665
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49666
# ❌ Predict: 4, True: 7
#
# 📌 Sample 49667
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49668
# ❌ Predict: 0, True: 8
#
# 📌 Sample 49669
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49670
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49671
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49672
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49673
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49674
# ❌ Predict: 9, True: 5
#
# 📌 Sample 49675
# ❌ Predict: 4, True: 2
#
# 📌 Sample 49676
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49677
# ❌ Predict: 0, True: 7
#
# 📌 Sample 49678
# ❌ Predict: 1, True: 8
#
# 📌 Sample 49679
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49680
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49681
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49682
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49683
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49684
# ❌ Predict: 7, True: 3
#
# 📌 Sample 49685
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49686
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49687
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49688
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49689
# ❌ Predict: 8, True: 9
#
# 📌 Sample 49690
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49691
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49692
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49693
# ❌ Predict: 7, True: 5
#
# 📌 Sample 49694
# ❌ Predict: 9, True: 6
#
# 📌 Sample 49695
# ❌ Predict: 4, True: 2
#
# 📌 Sample 49696
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49697
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49698
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49699
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49700
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49701
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49702
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49703
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49704
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49705
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49706
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49707
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49708
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49709
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49710
# ❌ Predict: 4, True: 7
#
# 📌 Sample 49711
# ❌ Predict: 8, True: 1
#
# 📌 Sample 49712
# ❌ Predict: 4, True: 6
#
# 📌 Sample 49713
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49714
# ❌ Predict: 7, True: 0
#
# 📌 Sample 49715
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49716
# ❌ Predict: 2, True: 4
#
# 📌 Sample 49717
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49718
# ❌ Predict: 4, True: 6
#
# 📌 Sample 49719
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49720
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49721
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49722
# ❌ Predict: 9, True: 8
#
# 📌 Sample 49723
# ❌ Predict: 7, True: 0
#
# 📌 Sample 49724
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49725
# ❌ Predict: 6, True: 3
#
# 📌 Sample 49726
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49727
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49728
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49729
# ❌ Predict: 5, True: 3
#
# 📌 Sample 49730
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49731
# ❌ Predict: 1, True: 8
#
# 📌 Sample 49732
# ❌ Predict: 4, True: 5
#
# 📌 Sample 49733
# ❌ Predict: 6, True: 5
#
# 📌 Sample 49734
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49735
# ❌ Predict: 2, True: 3
#
# 📌 Sample 49736
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49737
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49738
# ❌ Predict: 0, True: 2
#
# 📌 Sample 49739
# ❌ Predict: 9, True: 5
#
# 📌 Sample 49740
# ❌ Predict: 5, True: 3
#
# 📌 Sample 49741
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49742
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49743
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49744
# ❌ Predict: 2, True: 4
#
# 📌 Sample 49745
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49746
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49747
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49748
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49749
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49750
# ❌ Predict: 3, True: 1
#
# 📌 Sample 49751
# ❌ Predict: 6, True: 1
#
# 📌 Sample 49752
# ❌ Predict: 8, True: 1
#
# 📌 Sample 49753
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49754
# ❌ Predict: 5, True: 7
#
# 📌 Sample 49755
# ❌ Predict: 6, True: 2
#
# 📌 Sample 49756
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49757
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49758
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49759
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49760
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49761
# ❌ Predict: 2, True: 0
#
# 📌 Sample 49762
# ❌ Predict: 8, True: 2
#
# 📌 Sample 49763
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49764
# ❌ Predict: 3, True: 7
#
# 📌 Sample 49765
# ❌ Predict: 8, True: 0
#
# 📌 Sample 49766
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49767
# ❌ Predict: 2, True: 3
#
# 📌 Sample 49768
# ❌ Predict: 1, True: 0
#
# 📌 Sample 49769
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49770
# ❌ Predict: 2, True: 7
#
# 📌 Sample 49771
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49772
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49773
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49774
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49775
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49776
# ❌ Predict: 8, True: 6
#
# 📌 Sample 49777
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49778
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49779
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49780
# ❌ Predict: 7, True: 9
#
# 📌 Sample 49781
# ❌ Predict: 2, True: 0
#
# 📌 Sample 49782
# ❌ Predict: 0, True: 1
#
# 📌 Sample 49783
# ❌ Predict: 3, True: 7
#
# 📌 Sample 49784
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49785
# ❌ Predict: 7, True: 0
#
# 📌 Sample 49786
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49787
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49788
# ❌ Predict: 3, True: 6
#
# 📌 Sample 49789
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49790
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49791
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49792
# ❌ Predict: 1, True: 8
#
# 📌 Sample 49793
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49794
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49795
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49796
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49797
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49798
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49799
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49800
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49801
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49802
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49803
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49804
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49805
# ❌ Predict: 3, True: 7
#
# 📌 Sample 49806
# ❌ Predict: 0, True: 8
#
# 📌 Sample 49807
# ❌ Predict: 3, True: 4
#
# 📌 Sample 49808
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49809
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49810
# ❌ Predict: 1, True: 8
#
# 📌 Sample 49811
# ❌ Predict: 0, True: 3
#
# 📌 Sample 49812
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49813
# ❌ Predict: 8, True: 0
#
# 📌 Sample 49814
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49815
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49816
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49817
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49818
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49819
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49820
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49821
# ❌ Predict: 0, True: 4
#
# 📌 Sample 49822
# ❌ Predict: 0, True: 4
#
# 📌 Sample 49823
# ❌ Predict: 0, True: 5
#
# 📌 Sample 49824
# ❌ Predict: 3, True: 6
#
# 📌 Sample 49825
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49826
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49827
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49828
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49829
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49830
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49831
# ❌ Predict: 7, True: 5
#
# 📌 Sample 49832
# ❌ Predict: 4, True: 3
#
# 📌 Sample 49833
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49834
# ❌ Predict: 0, True: 1
#
# 📌 Sample 49835
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49836
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49837
# ❌ Predict: 4, True: 6
#
# 📌 Sample 49838
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49839
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49840
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49841
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49842
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49843
# ❌ Predict: 6, True: 3
#
# 📌 Sample 49844
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49845
# ❌ Predict: 8, True: 9
#
# 📌 Sample 49846
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49847
# ❌ Predict: 2, True: 5
#
# 📌 Sample 49848
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49849
# ❌ Predict: 0, True: 7
#
# 📌 Sample 49850
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49851
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49852
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49853
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49854
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49855
# ❌ Predict: 9, True: 0
#
# 📌 Sample 49856
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49857
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49858
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49859
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49860
# ❌ Predict: 4, True: 5
#
# 📌 Sample 49861
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49862
# ❌ Predict: 5, True: 6
#
# 📌 Sample 49863
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49864
# ❌ Predict: 4, True: 9
#
# 📌 Sample 49865
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49866
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49867
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49868
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49869
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49870
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49871
# ❌ Predict: 4, True: 0
#
# 📌 Sample 49872
# ❌ Predict: 5, True: 4
#
# 📌 Sample 49873
# ❌ Predict: 6, True: 3
#
# 📌 Sample 49874
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49875
# ❌ Predict: 1, True: 2
#
# 📌 Sample 49876
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49877
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49878
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49879
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49880
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49881
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49882
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49883
# ❌ Predict: 2, True: 4
#
# 📌 Sample 49884
# ❌ Predict: 6, True: 3
#
# 📌 Sample 49885
# ❌ Predict: 4, True: 2
#
# 📌 Sample 49886
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49887
# ❌ Predict: 3, True: 0
#
# 📌 Sample 49888
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49889
# ❌ Predict: 4, True: 7
#
# 📌 Sample 49890
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49891
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49892
# ❌ Predict: 4, True: 2
#
# 📌 Sample 49893
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49894
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49895
# ❌ Predict: 4, True: 0
#
# 📌 Sample 49896
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49897
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49898
# ❌ Predict: 3, True: 2
#
# 📌 Sample 49899
# ❌ Predict: 8, True: 9
#
# 📌 Sample 49900
# ❌ Predict: 0, True: 8
#
# 📌 Sample 49901
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49902
# ❌ Predict: 2, True: 6
#
# 📌 Sample 49903
# ❌ Predict: 2, True: 7
#
# 📌 Sample 49904
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49905
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49906
# ❌ Predict: 2, True: 0
#
# 📌 Sample 49907
# ❌ Predict: 2, True: 0
#
# 📌 Sample 49908
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49909
# ❌ Predict: 6, True: 5
#
# 📌 Sample 49910
# ❌ Predict: 0, True: 6
#
# 📌 Sample 49911
# ❌ Predict: 2, True: 4
#
# 📌 Sample 49912
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49913
# ❌ Predict: 9, True: 5
#
# 📌 Sample 49914
# ❌ Predict: 1, True: 9
#
# 📌 Sample 49915
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49916
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49917
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49918
# ❌ Predict: 4, True: 3
#
# 📌 Sample 49919
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49920
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49921
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49922
# ❌ Predict: 9, True: 8
#
# 📌 Sample 49923
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49924
# ❌ Predict: 4, True: 5
#
# 📌 Sample 49925
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49926
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49927
# ✔ Predict: 3, True: 3
#
# 📌 Sample 49928
# ❌ Predict: 4, True: 7
#
# 📌 Sample 49929
# ❌ Predict: 0, True: 4
#
# 📌 Sample 49930
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49931
# ❌ Predict: 4, True: 5
#
# 📌 Sample 49932
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49933
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49934
# ❌ Predict: 6, True: 2
#
# 📌 Sample 49935
# ❌ Predict: 8, True: 3
#
# 📌 Sample 49936
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49937
# ✔ Predict: 2, True: 2
#
# 📌 Sample 49938
# ❌ Predict: 9, True: 1
#
# 📌 Sample 49939
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49940
# ❌ Predict: 7, True: 4
#
# 📌 Sample 49941
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49942
# ❌ Predict: 0, True: 8
#
# 📌 Sample 49943
# ❌ Predict: 6, True: 4
#
# 📌 Sample 49944
# ❌ Predict: 3, True: 6
#
# 📌 Sample 49945
# ❌ Predict: 4, True: 7
#
# 📌 Sample 49946
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49947
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49948
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49949
# ❌ Predict: 7, True: 5
#
# 📌 Sample 49950
# ❌ Predict: 0, True: 2
#
# 📌 Sample 49951
# ❌ Predict: 9, True: 6
#
# 📌 Sample 49952
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49953
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49954
# ✔ Predict: 8, True: 8
#
# 📌 Sample 49955
# ✔ Predict: 5, True: 5
#
# 📌 Sample 49956
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49957
# ❌ Predict: 5, True: 3
#
# 📌 Sample 49958
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49959
# ❌ Predict: 4, True: 7
#
# 📌 Sample 49960
# ❌ Predict: 3, True: 7
#
# 📌 Sample 49961
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49962
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49963
# ✔ Predict: 6, True: 6
#
# 📌 Sample 49964
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49965
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49966
# ❌ Predict: 6, True: 1
#
# 📌 Sample 49967
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49968
# ❌ Predict: 3, True: 0
#
# 📌 Sample 49969
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49970
# ❌ Predict: 4, True: 2
#
# 📌 Sample 49971
# ❌ Predict: 3, True: 0
#
# 📌 Sample 49972
# ❌ Predict: 5, True: 3
#
# 📌 Sample 49973
# ❌ Predict: 5, True: 2
#
# 📌 Sample 49974
# ✔ Predict: 1, True: 1
#
# 📌 Sample 49975
# ❌ Predict: 4, True: 2
#
# 📌 Sample 49976
# ❌ Predict: 4, True: 3
#
# 📌 Sample 49977
# ✔ Predict: 4, True: 4
#
# 📌 Sample 49978
# ✔ Predict: 7, True: 7
#
# 📌 Sample 49979
# ✔ Predict: 0, True: 0
#
# 📌 Sample 49980
# ✔ Predict: 9, True: 9
#
# 📌 Sample 49981
# ❌ Predict: 5, True: 2
#
# 📌 Sample 49982
# ❌ Predict: 3, True: 5
#
# 📌 Sample 49983
# ✔ Predict: 3, True: 3
# Epoch 1/1 - Loss: 1.6173 - Acc: 0.4054 - Time: 9899.14s
#     Conv2D: 5623.29s | ReLU: 718.66s | MaxPool: 398.77s | Flatten: 114.31s | FC: 2025.72s | Softmax: 2.40s

# %%
func.plot_details("Data/log/details_log_cuda_ver4_50000_op_1.csv")

# %%
func.plot_compare_details_customized(
    "Data/log/details_log_cuda_ver4_50000_1.csv",
    "Data/log/details_log_cuda_ver4_50000_op_1.csv",
    "Numba",
    "Numba op 1"
)

# %%
# func.plot_timeline_from_log(
#     "Data/log/training_log_numpy_50000_10.csv",
#     columns = ["Accuracy"],
#     title = "Accuracy over epochs",
#     ylabel = "Accuracy",
# )

# %% [markdown]
# #### Nhận xét chung
# - Từ bây giờ có lẽ ta chỉ cần so sánh những phiên bản Numba với nhau vì phiên bản Python thuần gần như không thể nào đủ sức so sánh được nữa.
#
# - Lớp Conv2D có cải thiện đôi chút.
#
# - Khi chạy full 50000 ảnh thì vẫn khá lâu.

# %% [markdown]
# ### Định hướng tiếp theo
#
# Phát triển một phiên bản song song tối ưu hóa 2 bằng **shared memory** từ phiên bản song song cơ bản nhất
